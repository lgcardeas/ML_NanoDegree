# %% [markdown]
# # Deploy and monitor a machine learning workflow for Image Classification

# %% [markdown]
# ## Setting up this notebook
#
# Notes about the instance size and kernel setup: this notebook has been tested on
#
# 1. The `Python 3 (Data Science)` kernel
# 2. The `ml.t3.medium` Sagemaker notebook instance
#
# ## Data Staging
#
# We'll use a sample dataset called CIFAR to simulate the challenges Scones Unlimited are facing in Image Classification. In order to start working with CIFAR we'll need to:
#
# 1. Extract the data from a hosting service
# 2. Transform it into a usable shape and format
# 3. Load it into a production system
#
# In other words, we're going to do some simple ETL!
#
# ### 1. Extract the data from the hosting service
#
# In the cell below, define a function `extract_cifar_data` that extracts python version of the CIFAR-100 dataset. The CIFAR dataaset is open source and generously hosted by the University of Toronto at: https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz

# %%
import requests

def extract_cifar_data(url, filename="cifar.tar.gz"):
    """A function for extracting the CIFAR-100 dataset and storing it as a gzipped file
    
    Arguments:
    url      -- the URL where the dataset is hosted
    filename -- the full path where the dataset will be written
    """
    # Todo: request the data from the data url
    # Hint: use `requests.get` method
    r = requests.get(url)
    with open(filename, "wb") as file_context:
        file_context.write(r.content)
    return

# %% [markdown]
# Let's test it out! Run the following cell and check whether a new file `cifar.tar.gz` is created in the file explorer.

# %%
extract_cifar_data("https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz")

# %% [markdown]
# ### 2. Transform the data into a usable shape and format
#
# Clearly, distributing the data as a gzipped archive makes sense for the hosting service! It saves on bandwidth, storage, and it's a widely-used archive format. In fact, it's so widely used that the Python community ships a utility for working with them, `tarfile`, as part of its Standard Library. Execute the following cell to decompress your extracted dataset:

# %%
import tarfile

with tarfile.open("cifar.tar.gz", "r:gz") as tar:
    tar.extractall()

# %% [markdown]
# A new folder `cifar-100-python` should be created, containing `meta`, `test`, and `train` files. These files are `pickles` and the [CIFAR homepage](https://www.cs.toronto.edu/~kriz/cifar.html) provides a simple script that can be used to load them. We've adapted the script below for you to run:

# %%
import pickle

with open("./cifar-100-python/meta", "rb") as f:
    dataset_meta = pickle.load(f, encoding='bytes')

with open("./cifar-100-python/test", "rb") as f:
    dataset_test = pickle.load(f, encoding='bytes')

with open("./cifar-100-python/train", "rb") as f:
    dataset_train = pickle.load(f, encoding='bytes')

# %%
# Feel free to explore the datasets

dataset_train.keys()
# dataset_train[b'data'][0]
# len(dataset_train[b'data'][0]) === 32*32*3
# Out:
# dict_keys([b'filenames', b'batch_label', b'fine_labels', b'coarse_labels', b'data'])

# %% [markdown]
# As documented on the homepage, `b'data'` contains rows of 3073 unsigned integers, representing three channels (red, green, and blue) for one 32x32 pixel image per row.

# %%
32*32*3
# Out:
# 3072

# %% [markdown]
# For a simple gut-check, let's transform one of our images. Each 1024 items in a row is a channel (red, green, then blue). Each 32 items in the channel are a row in the 32x32 image. Using python, we can stack these channels into a 32x32x3 array, and save it as a PNG file:

# %%
import numpy as np

# Each 1024 in a row is a channel (red, green, then blue)
row = dataset_train[b'data'][0]
red, green, blue = row[0:1024], row[1024:2048], row[2048:]

# Each 32 items in the channel are a row in the 32x32 image
red = red.reshape(32,32)
green = green.reshape(32,32)
blue = blue.reshape(32,32)

# Combine the channels into a 32x32x3 image!
combined = np.dstack((red,green,blue))

len(combined)
# Out:
# 32

# %% [markdown]
# For a more concise version, consider the following:

# %%
# All in one:
test_image = np.dstack((
    row[0:1024].reshape(32,32),
    row[1024:2048].reshape(32,32),
    row[2048:].reshape(32,32)
))

# %%
import matplotlib.pyplot as plt
plt.imshow(test_image);

# %% [markdown]
# Looks like a cow! Let's check the label. `dataset_meta` contains label names in order, and `dataset_train` has a list of labels for each row.

# %%
dataset_train[b'fine_labels'][0]
# Out:
# 19

# %% [markdown]
# Our image has a label of `19`, so let's see what the 19th item is in the list of label names.

# %%
print(dataset_meta[b'fine_label_names'][19])
# Out:
# b'cattle'

# %% [markdown]
# Ok! 'cattle' sounds about right. By the way, using the previous two lines we can do:

# %%
n = 0
print(dataset_meta[b'fine_label_names'][dataset_train[b'fine_labels'][n]])
# Out:
# b'cattle'

# %% [markdown]
# Now we know how to check labels, is there a way that we can also check file names? `dataset_train` also contains a `b'filenames'` key. Let's see what we have here:

# %%
print(dataset_train[b'filenames'][0])
# Out:
# b'bos_taurus_s_000507.png'

# %% [markdown]
# "Taurus" is the name of a subspecies of cattle, so this looks like a pretty reasonable filename. To save an image we can also do:

# %%
plt.imsave("file.png", test_image)

# %% [markdown]
# Your new PNG file should now appear in the file explorer -- go ahead and pop it open to see!
#
# Now that you know how to reshape the images, save them as files, and capture their filenames and labels, let's just capture all the bicycles and motorcycles and save them. Scones Unlimited can use a model that tells these apart to route delivery drivers automatically.
#
# In the following cell, identify the label numbers for Bicycles and Motorcycles:

# %%
# %mkdir motorcycle
# %mkdir bicycle

import pandas as pd

# Todo: Filter the dataset_train and dataset_meta objects to find the label numbers for Bicycle and Motorcycles
bicycle_label = dataset_meta[b'fine_label_names'].index(b'bicycle')
motorcycle_label = dataset_meta[b'fine_label_names'].index(b'motorcycle')

# COMMENT, this is not how the project expect to save it, 
#  but, good solution

# key = { bicycle_label: 'bicycle', motorcycle_label: 'motorcycle' }
# for (i, label) in enumerate(dataset_train[b'fine_labels']):
#     if label != motorcycle_label and label != bicycle_label:
#         continue
    
#     # print(f"found {label}, {dataset_train[b'filenames'][i]}")
    
#     image = np.dstack((
#         dataset_train[b'data'][i][0:1024].reshape(32,32),
#         dataset_train[b'data'][i][1024:2048].reshape(32,32),
#         dataset_train[b'data'][i][2048:].reshape(32,32)
#     ))

#     # plt.imshow(motorcycle_image)
#     print(f"saving {key[label]}/{dataset_train[b'filenames'][i]}")
#     plt.imsave(f"{key[label]}/{dataset_train[b'filenames'][i].decode('utf-8')}", image)

print(f"bicycle_label number {bicycle_label} ")
print(f"motocycle_label number {motorcycle_label} ")
# Out:
# mkdir: cannot create directory ‘motorcycle’: File exists
# mkdir: cannot create directory ‘bicycle’: File exists
# bicycle_label number 8
# motocycle_label number 48

# %% [markdown]
# Good job! We only need objects with label 8 and 48 -- this drastically simplifies our handling of the data! Below we construct a dataframe for you, and you can safely drop the rows that don't contain observations about bicycles and motorcycles. Fill in the missing lines below to drop all other rows:

# %%
#Construct the dataframe
df_train = pd.DataFrame({
    "filenames": dataset_train[b'filenames'],
    "labels": dataset_train[b'fine_labels'],
    "row": range(len(dataset_train[b'filenames']))
})

# Drop all rows from df_train where label is not 8 or 48
df_train = df_train[df_train['labels'].isin([bicycle_label, motorcycle_label])]

# Decode df_train.filenames so they are regular strings
df_train["filenames"] = df_train["filenames"].apply(
    lambda x: x.decode("utf-8")
)

print(f"\n df_train.head(): \n{df_train.head()}")

df_test = pd.DataFrame({
    "filenames": dataset_test[b'filenames'],
    "labels": dataset_test[b'fine_labels'],
    "row": range(len(dataset_test[b'filenames']))
})

# # Drop all rows from df_test where label is not 8 or 48
df_test = df_test[df_test['labels'].isin([bicycle_label, motorcycle_label])]

# Decode df_test.filenames so they are regular strings
df_test["filenames"] = df_test["filenames"].apply(
    lambda x: x.decode("utf-8")
)
print(f"\n df_test.head(): \n{df_test.head()}")
# Out:
#  df_train.head():
#                    filenames  labels  row
# 16         bike_s_000682.png       8   16
# 30         bike_s_000127.png       8   30
# 130       cycle_s_002598.png       8  130
# 152    minibike_s_000824.png      48  152
# 195  motorcycle_s_001856.png      48  195
#
#  df_test.head():
#                          filenames  labels  row
# 27        safety_bike_s_000390.png       8   27
# 28               bike_s_000658.png       8   28
# 116        velocipede_s_001744.png       8  116
# 161              bike_s_000643.png       8  161
# 319  ordinary_bicycle_s_000437.png       8  319

# %% [markdown]
# Now that the data is filtered for just our classes, we can save all our images.

# %%
# !mkdir ./train
# !mkdir ./test

# %% [markdown]
# In the previous sections we introduced you to several key snippets of code:
#
# 1. Grabbing the image data:
#
# ```python
# dataset_train[b'data'][0]
# ```
#
# 2. A simple idiom for stacking the image data into the right shape
#
# ```python
# import numpy as np
# np.dstack((
#     row[0:1024].reshape(32,32),
#     row[1024:2048].reshape(32,32),
#     row[2048:].reshape(32,32)
# ))
# ```
#
# 3. A simple `matplotlib` utility for saving images
#
# ```python
# plt.imsave(path+row['filenames'], target)
# ```
#
# Compose these together into a function that saves all the images into the `./test` and `./train` directories. Use the comments in the body of the `save_images` function below to guide your construction of the function:

# %%
def save_image(file_name, data):
    #Grab the image data in row-major form
    img = np.dstack((
        data[0:1024].reshape(32,32),
        data[1024:2048].reshape(32,32),
        data[2048:].reshape(32,32)
    ))
    
    # Return any signal data you want for debugging
    try:
        plt.imsave(file_name, img)
    except Exception as e:
        print(f"{e=}")
        return False

    return True

for (i, row) in df_train.iterrows():
    save_image(f"train/{row['filenames']}", dataset_train[b'data'][row['row']])

for (i, row) in df_test.iterrows():
    save_image(f"test/{row['filenames']}", dataset_test[b'data'][row['row']])

# %% [markdown]
# ### 3. Load the data
#
# Now we can load the data into S3.
#
# Using the sagemaker SDK grab the current region, execution role, and bucket.

# %%
import sagemaker
import boto3

bucket= sagemaker.Session().default_bucket()
print("Default Bucket: {}".format(bucket))

region = boto3.Session().region_name
print("AWS Region: {}".format(region))

role = sagemaker.get_execution_role()
print("RoleArn: {}".format(role))
# Out:
# Default Bucket: sagemaker-us-east-1-072298625118
# AWS Region: us-east-1
# RoleArn: arn:aws:iam::072298625118:role/service-role/AmazonSageMaker-ExecutionRole-20240611T084741

# %% [markdown]
# With this data we can easily sync your data up into S3!

# %%
import os

os.environ["DEFAULT_S3_BUCKET"] = bucket
# !aws s3 sync ./train s3://${DEFAULT_S3_BUCKET}/train/
# !aws s3 sync ./test s3://${DEFAULT_S3_BUCKET}/test/
# Out:
# upload: train/bicycle_s_000017.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000017.png
# upload: train/bicycle_s_000038.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000038.png
# upload: train/bicycle_s_000021.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000021.png
# upload: train/bicycle_s_000039.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000039.png
# upload: train/bicycle_s_000051.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000051.png
# upload: train/bicycle_s_000066.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000066.png
# upload: train/bicycle_s_000043.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000043.png
# upload: train/bicycle_s_000099.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000099.png
# upload: train/bicycle_s_000035.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000035.png
# upload: train/bicycle_s_000124.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000124.png
# upload: train/bicycle_s_000071.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000071.png
# upload: train/bicycle_s_000147.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000147.png
# upload: train/bicycle_s_000159.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000159.png
# upload: train/bicycle_s_000156.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000156.png
# upload: train/bicycle_s_000137.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000137.png
# upload: train/bicycle_s_000180.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000180.png
# upload: train/bicycle_s_000149.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000149.png
# upload: train/bicycle_s_000235.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000235.png
# upload: train/bicycle_s_000279.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000279.png
# upload: train/bicycle_s_000369.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000369.png
# upload: train/bicycle_s_000243.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000243.png
# upload: train/bicycle_s_000314.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000314.png
# upload: train/bicycle_s_000392.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000392.png
# upload: train/bicycle_s_000231.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000231.png
# upload: train/bicycle_s_000282.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000282.png
# upload: train/bicycle_s_000408.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000408.png
# upload: train/bicycle_s_000396.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000396.png
# upload: train/bicycle_s_000399.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000399.png
# upload: train/bicycle_s_000371.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000371.png
# upload: train/bicycle_s_000435.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000435.png
# upload: train/bicycle_s_000491.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000491.png
# upload: train/bicycle_s_000522.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000522.png
# upload: train/bicycle_s_000467.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000467.png
# upload: train/bicycle_s_000536.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000536.png
# upload: train/bicycle_s_000463.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000463.png
# upload: train/bicycle_s_000537.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000537.png
# upload: train/bicycle_s_000569.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000569.png
# upload: train/bicycle_s_000668.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000668.png
# upload: train/bicycle_s_000561.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000561.png
# upload: train/bicycle_s_000437.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000437.png
# upload: train/bicycle_s_000667.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000667.png
# upload: train/bicycle_s_000759.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000759.png
# upload: train/bicycle_s_000723.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000723.png
# upload: train/bicycle_s_000781.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000781.png
# upload: train/bicycle_s_000774.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000774.png
# upload: train/bicycle_s_000753.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000753.png
# upload: train/bicycle_s_000785.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000785.png
# upload: train/bicycle_s_000778.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000778.png
# upload: train/bicycle_s_000822.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000822.png
# upload: train/bicycle_s_000775.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000775.png
# upload: train/bicycle_s_000782.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000782.png
# upload: train/bicycle_s_000546.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000546.png
# upload: train/bicycle_s_000861.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000861.png
# upload: train/bicycle_s_000951.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000951.png
# upload: train/bicycle_s_001168.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_001168.png
# upload: train/bicycle_s_000986.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000986.png
# upload: train/bicycle_s_001002.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_001002.png
# upload: train/bicycle_s_000996.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000996.png
# upload: train/bicycle_s_000829.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000829.png
# upload: train/bicycle_s_001111.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_001111.png
# upload: train/bicycle_s_001174.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_001174.png
# upload: train/bicycle_s_001203.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_001203.png
# upload: train/bicycle_s_001228.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_001228.png
# upload: train/bicycle_s_001247.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_001247.png
# upload: train/bicycle_s_001245.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_001245.png
# upload: train/bicycle_s_001205.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_001205.png
# upload: train/bicycle_s_001338.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_001338.png
# upload: train/bicycle_s_001348.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_001348.png
# upload: train/bicycle_s_000978.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_000978.png
# upload: train/bicycle_s_001388.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_001388.png
# upload: train/bicycle_s_001409.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_001409.png
# upload: train/bicycle_s_001411.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_001411.png
# upload: train/bicycle_s_001448.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_001448.png
# upload: train/bicycle_s_001554.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_001554.png
# upload: train/bicycle_s_001452.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_001452.png
# upload: train/bicycle_s_001569.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_001569.png
# upload: train/bicycle_s_001583.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_001583.png
# upload: train/bicycle_s_001663.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_001663.png
# upload: train/bicycle_s_001402.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_001402.png
# upload: train/bicycle_s_001642.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_001642.png
# upload: train/bicycle_s_001673.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_001673.png
# upload: train/bicycle_s_001688.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_001688.png
# upload: train/bicycle_s_001687.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_001687.png
# upload: train/bicycle_s_001470.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_001470.png
# upload: train/bicycle_s_001679.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_001679.png
# upload: train/bicycle_s_001814.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_001814.png
# upload: train/bicycle_s_001928.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_001928.png
# upload: train/bicycle_s_002005.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_002005.png
# upload: train/bicycle_s_001956.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_001956.png
# upload: train/bicycle_s_001681.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_001681.png
# upload: train/bicycle_s_001748.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_001748.png
# upload: train/bicycle_s_001693.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_001693.png
# upload: train/bicycle_s_001757.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_001757.png
# upload: train/bicycle_s_002049.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_002049.png
# upload: train/bicycle_s_002012.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_002012.png
# upload: train/bicycle_s_002029.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_002029.png
# upload: train/bicycle_s_002100.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_002100.png
# upload: train/bicycle_s_002129.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_002129.png
# upload: train/bicycle_s_001904.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_001904.png
# upload: train/bicycle_s_002218.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_002218.png
# upload: train/bicycle_s_002132.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_002132.png
# upload: train/bicycle_s_002222.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_002222.png
# upload: train/bicycle_s_002153.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_002153.png
# upload: train/bicycle_s_002237.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_002237.png
# upload: train/bicycle_s_002299.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_002299.png
# upload: train/bicycle_s_002374.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_002374.png
# upload: train/bicycle_s_002410.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_002410.png
# upload: train/bicycle_s_002258.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_002258.png
# upload: train/bicycle_s_002448.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_002448.png
# upload: train/bicycle_s_002247.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_002247.png
# upload: train/bicycle_s_002400.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_002400.png
# upload: train/bicycle_s_002338.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_002338.png
# upload: train/bicycle_s_002436.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_002436.png
# upload: train/bicycle_s_002475.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_002475.png
# upload: train/bicycle_s_002521.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_002521.png
# upload: train/bicycle_s_002373.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_002373.png
# upload: train/bicycle_s_002569.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_002569.png
# upload: train/bicycle_s_002624.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_002624.png
# upload: train/bicycle_s_002715.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_002715.png
# upload: train/bicycle_s_002728.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_002728.png
# upload: train/bicycle_s_002550.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_002550.png
# upload: train/bicycle_s_002725.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_002725.png
# upload: train/bicycle_s_002729.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_002729.png
# upload: train/bicycle_s_002669.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_002669.png
# upload: train/bicycle_s_002711.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_002711.png
# upload: train/bike_s_000003.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000003.png
# upload: train/bicycle_s_002759.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_002759.png
# upload: train/bike_s_000018.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000018.png
# upload: train/bike_s_000015.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000015.png
# upload: train/bike_s_000021.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000021.png
# upload: train/bike_s_000023.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000023.png
# upload: train/bike_s_000005.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000005.png
# upload: train/bicycle_s_002762.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_002762.png
# upload: train/bike_s_000024.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000024.png
# upload: train/bicycle_s_002661.png to s3://sagemaker-us-east-1-072298625118/train/bicycle_s_002661.png
# upload: train/bike_s_000026.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000026.png
# upload: train/bike_s_000025.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000025.png
# upload: train/bike_s_000040.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000040.png
# upload: train/bike_s_000035.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000035.png
# upload: train/bike_s_000111.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000111.png
# upload: train/bike_s_000062.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000062.png
# upload: train/bike_s_000121.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000121.png
# upload: train/bike_s_000034.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000034.png
# upload: train/bike_s_000001.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000001.png
# upload: train/bike_s_000051.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000051.png
# upload: train/bike_s_000127.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000127.png
# upload: train/bike_s_000129.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000129.png
# upload: train/bike_s_000162.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000162.png
# upload: train/bike_s_000164.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000164.png
# upload: train/bike_s_000256.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000256.png
# upload: train/bike_s_000299.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000299.png
# upload: train/bike_s_000302.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000302.png
# upload: train/bike_s_000304.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000304.png
# upload: train/bike_s_000336.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000336.png
# upload: train/bike_s_000392.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000392.png
# upload: train/bike_s_000390.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000390.png
# upload: train/bike_s_000237.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000237.png
# upload: train/bike_s_000397.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000397.png
# upload: train/bike_s_000204.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000204.png
# upload: train/bike_s_000474.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000474.png
# upload: train/bike_s_000364.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000364.png
# upload: train/bike_s_000154.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000154.png
# upload: train/bike_s_000522.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000522.png
# upload: train/bike_s_000544.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000544.png
# upload: train/bike_s_000506.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000506.png
# upload: train/bike_s_000516.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000516.png
# upload: train/bike_s_000593.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000593.png
# upload: train/bike_s_000628.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000628.png
# upload: train/bike_s_000545.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000545.png
# upload: train/bike_s_000722.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000722.png
# upload: train/bike_s_000855.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000855.png
# upload: train/bike_s_000657.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000657.png
# upload: train/bike_s_000679.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000679.png
# upload: train/bike_s_000990.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000990.png
# upload: train/bike_s_000934.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000934.png
# upload: train/bike_s_000926.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000926.png
# upload: train/bike_s_000555.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000555.png
# upload: train/bike_s_000682.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_000682.png
# upload: train/bike_s_001113.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001113.png
# upload: train/bike_s_001131.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001131.png
# upload: train/bike_s_001116.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001116.png
# upload: train/bike_s_001078.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001078.png
# upload: train/bike_s_001226.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001226.png
# upload: train/bike_s_001027.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001027.png
# upload: train/bike_s_001260.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001260.png
# upload: train/bike_s_001200.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001200.png
# upload: train/bike_s_001320.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001320.png
# upload: train/bike_s_001380.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001380.png
# upload: train/bike_s_001418.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001418.png
# upload: train/bike_s_001375.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001375.png
# upload: train/bike_s_001517.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001517.png
# upload: train/bike_s_001072.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001072.png
# upload: train/bike_s_001093.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001093.png
# upload: train/bike_s_001414.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001414.png
# upload: train/bike_s_001462.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001462.png
# upload: train/bike_s_001415.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001415.png
# upload: train/bike_s_001519.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001519.png
# upload: train/bike_s_001572.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001572.png
# upload: train/bike_s_001592.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001592.png
# upload: train/bike_s_001613.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001613.png
# upload: train/bike_s_001739.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001739.png
# upload: train/bike_s_001683.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001683.png
# upload: train/bike_s_001767.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001767.png
# upload: train/bike_s_001679.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001679.png
# upload: train/bike_s_001839.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001839.png
# upload: train/bike_s_001847.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001847.png
# upload: train/bike_s_001876.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001876.png
# upload: train/bike_s_001761.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001761.png
# upload: train/bike_s_001882.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001882.png
# upload: train/bike_s_001945.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001945.png
# upload: train/bike_s_001915.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001915.png
# upload: train/bike_s_001877.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001877.png
# upload: train/bike_s_001928.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001928.png
# upload: train/bike_s_002024.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_002024.png
# upload: train/bike_s_002033.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_002033.png
# upload: train/bike_s_001897.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001897.png
# upload: train/bike_s_002047.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_002047.png
# upload: train/bike_s_001980.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001980.png
# upload: train/bike_s_002109.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_002109.png
# upload: train/bike_s_002098.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_002098.png
# upload: train/bike_s_002139.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_002139.png
# upload: train/bike_s_002118.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_002118.png
# upload: train/bike_s_002090.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_002090.png
# upload: train/bike_s_002042.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_002042.png
# upload: train/bike_s_001827.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_001827.png
# upload: train/bike_s_002222.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_002222.png
# upload: train/bike_s_002283.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_002283.png
# upload: train/cycle_s_000042.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_000042.png
# upload: train/bike_s_002292.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_002292.png
# upload: train/bike_s_002288.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_002288.png
# upload: train/bike_s_002215.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_002215.png
# upload: train/bike_s_002164.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_002164.png
# upload: train/bike_s_002277.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_002277.png
# upload: train/cycle_s_000318.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_000318.png
# upload: train/bike_s_002203.png to s3://sagemaker-us-east-1-072298625118/train/bike_s_002203.png
# upload: train/cycle_s_000463.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_000463.png
# upload: train/cycle_s_000492.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_000492.png
# upload: train/cycle_s_000639.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_000639.png
# upload: train/cycle_s_000583.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_000583.png
# upload: train/cycle_s_000666.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_000666.png
# upload: train/cycle_s_000222.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_000222.png
# upload: train/cycle_s_000899.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_000899.png
# upload: train/cycle_s_000718.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_000718.png
# upload: train/cycle_s_000871.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_000871.png
# upload: train/cycle_s_001374.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_001374.png
# upload: train/cycle_s_001309.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_001309.png
# upload: train/cycle_s_001412.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_001412.png
# upload: train/cycle_s_001439.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_001439.png
# upload: train/cycle_s_001472.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_001472.png
# upload: train/cycle_s_001745.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_001745.png
# upload: train/cycle_s_001474.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_001474.png
# upload: train/cycle_s_001640.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_001640.png
# upload: train/cycle_s_001477.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_001477.png
# upload: train/cycle_s_001286.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_001286.png
# upload: train/cycle_s_001976.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_001976.png
# upload: train/cycle_s_001735.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_001735.png
# upload: train/cycle_s_001875.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_001875.png
# upload: train/cycle_s_002015.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_002015.png
# upload: train/cycle_s_002090.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_002090.png
# upload: train/cycle_s_002053.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_002053.png
# upload: train/cycle_s_002092.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_002092.png
# upload: train/cycle_s_001413.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_001413.png
# upload: train/cycle_s_002178.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_002178.png
# upload: train/cycle_s_002168.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_002168.png
# upload: train/cycle_s_002093.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_002093.png
# upload: train/cycle_s_002503.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_002503.png
# upload: train/cycle_s_002659.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_002659.png
# upload: train/cycle_s_002598.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_002598.png
# upload: train/cycle_s_002666.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_002666.png
# upload: train/cycle_s_002651.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_002651.png
# upload: train/cycle_s_002399.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_002399.png
# upload: train/cycle_s_002638.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_002638.png
# upload: train/cycle_s_002746.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_002746.png
# upload: train/cycle_s_002844.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_002844.png
# upload: train/cycle_s_002779.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_002779.png
# upload: train/cycle_s_002703.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_002703.png
# upload: train/cycle_s_003006.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_003006.png
# upload: train/cycle_s_002904.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_002904.png
# upload: train/cycle_s_003008.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_003008.png
# upload: train/cycle_s_003122.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_003122.png
# upload: train/cycle_s_003147.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_003147.png
# upload: train/cycle_s_002978.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_002978.png
# upload: train/cycle_s_002882.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_002882.png
# upload: train/cycle_s_003148.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_003148.png
# upload: train/dirt_bike_s_000003.png to s3://sagemaker-us-east-1-072298625118/train/dirt_bike_s_000003.png
# upload: train/cycle_s_003162.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_003162.png
# upload: train/cycle_s_003026.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_003026.png
# upload: train/dirt_bike_s_000005.png to s3://sagemaker-us-east-1-072298625118/train/dirt_bike_s_000005.png
# upload: train/cycle_s_003043.png to s3://sagemaker-us-east-1-072298625118/train/cycle_s_003043.png
# upload: train/dirt_bike_s_000030.png to s3://sagemaker-us-east-1-072298625118/train/dirt_bike_s_000030.png
# upload: train/dirt_bike_s_000017.png to s3://sagemaker-us-east-1-072298625118/train/dirt_bike_s_000017.png
# upload: train/dirt_bike_s_000059.png to s3://sagemaker-us-east-1-072298625118/train/dirt_bike_s_000059.png
# upload: train/dirt_bike_s_000134.png to s3://sagemaker-us-east-1-072298625118/train/dirt_bike_s_000134.png
# upload: train/dirt_bike_s_000119.png to s3://sagemaker-us-east-1-072298625118/train/dirt_bike_s_000119.png
# upload: train/minibike_s_000011.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000011.png
# upload: train/minibike_s_000010.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000010.png
# upload: train/minibike_s_000035.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000035.png
# upload: train/minibike_s_000099.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000099.png
# upload: train/minibike_s_000064.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000064.png
# upload: train/minibike_s_000102.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000102.png
# upload: train/dirt_bike_s_000124.png to s3://sagemaker-us-east-1-072298625118/train/dirt_bike_s_000124.png
# upload: train/minibike_s_000022.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000022.png
# upload: train/minibike_s_000116.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000116.png
# upload: train/minibike_s_000108.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000108.png
# upload: train/minibike_s_000110.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000110.png
# upload: train/minibike_s_000121.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000121.png
# upload: train/minibike_s_000127.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000127.png
# upload: train/minibike_s_000117.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000117.png
# upload: train/minibike_s_000036.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000036.png
# upload: train/minibike_s_000146.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000146.png
# upload: train/minibike_s_000149.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000149.png
# upload: train/minibike_s_000165.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000165.png
# upload: train/minibike_s_000244.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000244.png
# upload: train/minibike_s_000218.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000218.png
# upload: train/minibike_s_000130.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000130.png
# upload: train/minibike_s_000314.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000314.png
# upload: train/minibike_s_000203.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000203.png
# upload: train/minibike_s_000020.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000020.png
# upload: train/minibike_s_000335.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000335.png
# upload: train/minibike_s_000324.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000324.png
# upload: train/minibike_s_000362.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000362.png
# upload: train/minibike_s_000392.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000392.png
# upload: train/minibike_s_000401.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000401.png
# upload: train/minibike_s_000402.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000402.png
# upload: train/minibike_s_000350.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000350.png
# upload: train/minibike_s_000408.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000408.png
# upload: train/minibike_s_000427.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000427.png
# upload: train/minibike_s_000409.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000409.png
# upload: train/minibike_s_000340.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000340.png
# upload: train/minibike_s_000429.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000429.png
# upload: train/minibike_s_000435.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000435.png
# upload: train/minibike_s_000293.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000293.png
# upload: train/minibike_s_000451.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000451.png
# upload: train/minibike_s_000459.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000459.png
# upload: train/minibike_s_000498.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000498.png
# upload: train/minibike_s_000434.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000434.png
# upload: train/minibike_s_000511.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000511.png
# upload: train/minibike_s_000491.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000491.png
# upload: train/minibike_s_000485.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000485.png
# upload: train/minibike_s_000519.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000519.png
# upload: train/minibike_s_000522.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000522.png
# upload: train/minibike_s_000520.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000520.png
# upload: train/minibike_s_000527.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000527.png
# upload: train/minibike_s_000566.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000566.png
# upload: train/minibike_s_000567.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000567.png
# upload: train/minibike_s_000526.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000526.png
# upload: train/minibike_s_000507.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000507.png
# upload: train/minibike_s_000565.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000565.png
# upload: train/minibike_s_000613.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000613.png
# upload: train/minibike_s_000654.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000654.png
# upload: train/minibike_s_000518.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000518.png
# upload: train/minibike_s_000569.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000569.png
# upload: train/minibike_s_000652.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000652.png
# upload: train/minibike_s_000570.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000570.png
# upload: train/minibike_s_000690.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000690.png
# upload: train/minibike_s_000698.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000698.png
# upload: train/minibike_s_000701.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000701.png
# upload: train/minibike_s_000743.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000743.png
# upload: train/minibike_s_000738.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000738.png
# upload: train/minibike_s_000568.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000568.png
# upload: train/minibike_s_000800.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000800.png
# upload: train/minibike_s_000571.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000571.png
# upload: train/minibike_s_000824.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000824.png
# upload: train/minibike_s_000831.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000831.png
# upload: train/minibike_s_000855.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000855.png
# upload: train/minibike_s_000813.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000813.png
# upload: train/minibike_s_000741.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000741.png
# upload: train/minibike_s_000885.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000885.png
# upload: train/minibike_s_000914.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000914.png
# upload: train/minibike_s_000886.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000886.png
# upload: train/minibike_s_000830.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000830.png
# upload: train/minibike_s_000967.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000967.png
# upload: train/minibike_s_000906.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000906.png
# upload: train/minibike_s_000968.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000968.png
# upload: train/minibike_s_001079.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001079.png
# upload: train/minibike_s_000709.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000709.png
# upload: train/minibike_s_000820.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000820.png
# upload: train/minibike_s_000802.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_000802.png
# upload: train/minibike_s_001072.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001072.png
# upload: train/minibike_s_001017.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001017.png
# upload: train/minibike_s_001094.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001094.png
# upload: train/minibike_s_001179.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001179.png
# upload: train/minibike_s_001177.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001177.png
# upload: train/minibike_s_001157.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001157.png
# upload: train/minibike_s_001016.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001016.png
# upload: train/minibike_s_001249.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001249.png
# upload: train/minibike_s_001168.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001168.png
# upload: train/minibike_s_001250.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001250.png
# upload: train/minibike_s_001261.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001261.png
# upload: train/minibike_s_001191.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001191.png
# upload: train/minibike_s_001169.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001169.png
# upload: train/minibike_s_001270.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001270.png
# upload: train/minibike_s_001185.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001185.png
# upload: train/minibike_s_001294.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001294.png
# upload: train/minibike_s_001366.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001366.png
# upload: train/minibike_s_001348.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001348.png
# upload: train/minibike_s_001279.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001279.png
# upload: train/minibike_s_001275.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001275.png
# upload: train/minibike_s_001450.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001450.png
# upload: train/minibike_s_001417.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001417.png
# upload: train/minibike_s_001479.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001479.png
# upload: train/minibike_s_001345.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001345.png
# upload: train/minibike_s_001491.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001491.png
# upload: train/minibike_s_001496.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001496.png
# upload: train/minibike_s_001498.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001498.png
# upload: train/minibike_s_001344.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001344.png
# upload: train/minibike_s_001511.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001511.png
# upload: train/minibike_s_001458.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001458.png
# upload: train/minibike_s_001512.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001512.png
# upload: train/minibike_s_001539.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001539.png
# upload: train/minibike_s_001546.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001546.png
# upload: train/minibike_s_001506.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001506.png
# upload: train/minibike_s_001597.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001597.png
# upload: train/minibike_s_001573.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001573.png
# upload: train/minibike_s_001631.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001631.png
# upload: train/minibike_s_001558.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001558.png
# upload: train/minibike_s_001193.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001193.png
# upload: train/minibike_s_001540.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001540.png
# upload: train/minibike_s_001565.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001565.png
# upload: train/minibike_s_001638.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001638.png
# upload: train/minibike_s_001691.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001691.png
# upload: train/minibike_s_001701.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001701.png
# upload: train/minibike_s_001639.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001639.png
# upload: train/minibike_s_001575.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001575.png
# upload: train/minibike_s_001731.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001731.png
# upload: train/minibike_s_001747.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001747.png
# upload: train/minibike_s_001734.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001734.png
# upload: train/minibike_s_001771.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001771.png
# upload: train/minibike_s_001829.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001829.png
# upload: train/minibike_s_001789.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001789.png
# upload: train/minibike_s_001653.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001653.png
# upload: train/minibike_s_001689.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001689.png
# upload: train/minibike_s_001827.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001827.png
# upload: train/minibike_s_001863.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001863.png
# upload: train/minibike_s_001838.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001838.png
# upload: train/minibike_s_001865.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001865.png
# upload: train/minibike_s_001767.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001767.png
# upload: train/minibike_s_001921.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001921.png
# upload: train/minibike_s_001880.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001880.png
# upload: train/minibike_s_001944.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001944.png
# upload: train/minibike_s_001972.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001972.png
# upload: train/minibike_s_001836.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001836.png
# upload: train/minibike_s_001881.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001881.png
# upload: train/minibike_s_001996.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001996.png
# upload: train/minibike_s_001870.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001870.png
# upload: train/minibike_s_001873.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001873.png
# upload: train/minibike_s_001885.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001885.png
# upload: train/minibike_s_001969.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001969.png
# upload: train/minibike_s_001917.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_001917.png
# upload: train/minibike_s_002048.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_002048.png
# upload: train/minibike_s_002030.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_002030.png
# upload: train/minibike_s_002084.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_002084.png
# upload: train/minibike_s_002115.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_002115.png
# upload: train/minibike_s_002038.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_002038.png
# upload: train/minibike_s_002124.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_002124.png
# upload: train/minibike_s_002046.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_002046.png
# upload: train/minibike_s_002137.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_002137.png
# upload: train/minibike_s_002163.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_002163.png
# upload: train/minibike_s_002146.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_002146.png
# upload: train/minibike_s_002182.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_002182.png
# upload: train/minibike_s_002186.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_002186.png
# upload: train/minibike_s_002196.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_002196.png
# upload: train/minibike_s_002218.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_002218.png
# upload: train/minibike_s_002130.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_002130.png
# upload: train/minibike_s_002198.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_002198.png
# upload: train/moped_s_000009.png to s3://sagemaker-us-east-1-072298625118/train/moped_s_000009.png
# upload: train/minibike_s_002176.png to s3://sagemaker-us-east-1-072298625118/train/minibike_s_002176.png
# upload: train/moped_s_000021.png to s3://sagemaker-us-east-1-072298625118/train/moped_s_000021.png
# upload: train/moped_s_000004.png to s3://sagemaker-us-east-1-072298625118/train/moped_s_000004.png
# upload: train/moped_s_000034.png to s3://sagemaker-us-east-1-072298625118/train/moped_s_000034.png
# ...
# upload: test/cycle_s_001953.png to s3://sagemaker-us-east-1-072298625118/test/cycle_s_001953.png
# upload: test/minibike_s_000055.png to s3://sagemaker-us-east-1-072298625118/test/minibike_s_000055.png
# upload: test/cycle_s_002964.png to s3://sagemaker-us-east-1-072298625118/test/cycle_s_002964.png
# upload: test/minibike_s_000075.png to s3://sagemaker-us-east-1-072298625118/test/minibike_s_000075.png
# upload: test/dirt_bike_s_000001.png to s3://sagemaker-us-east-1-072298625118/test/dirt_bike_s_000001.png
# upload: test/minibike_s_000052.png to s3://sagemaker-us-east-1-072298625118/test/minibike_s_000052.png
# upload: test/minibike_s_000254.png to s3://sagemaker-us-east-1-072298625118/test/minibike_s_000254.png
# upload: test/minibike_s_000290.png to s3://sagemaker-us-east-1-072298625118/test/minibike_s_000290.png
# upload: test/minibike_s_000497.png to s3://sagemaker-us-east-1-072298625118/test/minibike_s_000497.png
# upload: test/minibike_s_000792.png to s3://sagemaker-us-east-1-072298625118/test/minibike_s_000792.png
# upload: test/minibike_s_000288.png to s3://sagemaker-us-east-1-072298625118/test/minibike_s_000288.png
# upload: test/minibike_s_000573.png to s3://sagemaker-us-east-1-072298625118/test/minibike_s_000573.png
# upload: test/minibike_s_000398.png to s3://sagemaker-us-east-1-072298625118/test/minibike_s_000398.png
# upload: test/minibike_s_000801.png to s3://sagemaker-us-east-1-072298625118/test/minibike_s_000801.png
# upload: test/minibike_s_000913.png to s3://sagemaker-us-east-1-072298625118/test/minibike_s_000913.png
# upload: test/minibike_s_000309.png to s3://sagemaker-us-east-1-072298625118/test/minibike_s_000309.png
# upload: test/minibike_s_000828.png to s3://sagemaker-us-east-1-072298625118/test/minibike_s_000828.png
# upload: test/cycle_s_002661.png to s3://sagemaker-us-east-1-072298625118/test/cycle_s_002661.png
# upload: test/minibike_s_000947.png to s3://sagemaker-us-east-1-072298625118/test/minibike_s_000947.png
# upload: test/minibike_s_001441.png to s3://sagemaker-us-east-1-072298625118/test/minibike_s_001441.png
# upload: test/minibike_s_001473.png to s3://sagemaker-us-east-1-072298625118/test/minibike_s_001473.png
# upload: test/minibike_s_001605.png to s3://sagemaker-us-east-1-072298625118/test/minibike_s_001605.png
# upload: test/minibike_s_000880.png to s3://sagemaker-us-east-1-072298625118/test/minibike_s_000880.png
# upload: test/minibike_s_000960.png to s3://sagemaker-us-east-1-072298625118/test/minibike_s_000960.png
# upload: test/minibike_s_001547.png to s3://sagemaker-us-east-1-072298625118/test/minibike_s_001547.png
# upload: test/minibike_s_001089.png to s3://sagemaker-us-east-1-072298625118/test/minibike_s_001089.png
# upload: test/minibike_s_001651.png to s3://sagemaker-us-east-1-072298625118/test/minibike_s_001651.png
# upload: test/minibike_s_001732.png to s3://sagemaker-us-east-1-072298625118/test/minibike_s_001732.png
# upload: test/minibike_s_001867.png to s3://sagemaker-us-east-1-072298625118/test/minibike_s_001867.png
# upload: test/minibike_s_002230.png to s3://sagemaker-us-east-1-072298625118/test/minibike_s_002230.png
# upload: test/moped_s_000007.png to s3://sagemaker-us-east-1-072298625118/test/moped_s_000007.png
# upload: test/minibike_s_002173.png to s3://sagemaker-us-east-1-072298625118/test/minibike_s_002173.png
# upload: test/moped_s_000033.png to s3://sagemaker-us-east-1-072298625118/test/moped_s_000033.png
# upload: test/minibike_s_002227.png to s3://sagemaker-us-east-1-072298625118/test/minibike_s_002227.png
# upload: test/moped_s_000064.png to s3://sagemaker-us-east-1-072298625118/test/moped_s_000064.png
# upload: test/motorbike_s_000005.png to s3://sagemaker-us-east-1-072298625118/test/motorbike_s_000005.png
# upload: test/minibike_s_001893.png to s3://sagemaker-us-east-1-072298625118/test/minibike_s_001893.png
# upload: test/motorbike_s_000121.png to s3://sagemaker-us-east-1-072298625118/test/motorbike_s_000121.png
# upload: test/motorbike_s_000126.png to s3://sagemaker-us-east-1-072298625118/test/motorbike_s_000126.png
# upload: test/moped_s_000306.png to s3://sagemaker-us-east-1-072298625118/test/moped_s_000306.png
# upload: test/motorbike_s_000465.png to s3://sagemaker-us-east-1-072298625118/test/motorbike_s_000465.png
# upload: test/motorbike_s_000324.png to s3://sagemaker-us-east-1-072298625118/test/motorbike_s_000324.png
# upload: test/motorbike_s_000333.png to s3://sagemaker-us-east-1-072298625118/test/motorbike_s_000333.png
# upload: test/motorcycle_s_000007.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_000007.png
# upload: test/motorbike_s_000135.png to s3://sagemaker-us-east-1-072298625118/test/motorbike_s_000135.png
# upload: test/motorcycle_s_000040.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_000040.png
# upload: test/motorcycle_s_000060.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_000060.png
# upload: test/motorbike_s_000433.png to s3://sagemaker-us-east-1-072298625118/test/motorbike_s_000433.png
# upload: test/minibike_s_000505.png to s3://sagemaker-us-east-1-072298625118/test/minibike_s_000505.png
# upload: test/motorbike_s_000629.png to s3://sagemaker-us-east-1-072298625118/test/motorbike_s_000629.png
# upload: test/motorcycle_s_000171.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_000171.png
# upload: test/motorcycle_s_000222.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_000222.png
# upload: test/motorcycle_s_000049.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_000049.png
# upload: test/motorcycle_s_000141.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_000141.png
# upload: test/motorcycle_s_000139.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_000139.png
# upload: test/motorcycle_s_000211.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_000211.png
# upload: test/motorcycle_s_000323.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_000323.png
# upload: test/motorcycle_s_000446.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_000446.png
# upload: test/motorcycle_s_000450.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_000450.png
# upload: test/motorcycle_s_000427.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_000427.png
# upload: test/motorcycle_s_000494.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_000494.png
# upload: test/motorcycle_s_000042.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_000042.png
# upload: test/motorcycle_s_000063.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_000063.png
# upload: test/motorcycle_s_000530.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_000530.png
# upload: test/motorcycle_s_000602.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_000602.png
# upload: test/motorcycle_s_000512.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_000512.png
# upload: test/motorcycle_s_000615.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_000615.png
# upload: test/motorcycle_s_000685.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_000685.png
# upload: test/motorcycle_s_000485.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_000485.png
# upload: test/motorcycle_s_000739.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_000739.png
# upload: test/motorcycle_s_000679.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_000679.png
# upload: test/motorcycle_s_000606.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_000606.png
# upload: test/motorcycle_s_000797.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_000797.png
# upload: test/motorcycle_s_000352.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_000352.png
# upload: test/motorcycle_s_000825.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_000825.png
# upload: test/motorcycle_s_000876.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_000876.png
# upload: test/motorcycle_s_000866.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_000866.png
# upload: test/motorcycle_s_000963.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_000963.png
# upload: test/motorcycle_s_001261.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_001261.png
# upload: test/motorcycle_s_001269.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_001269.png
# upload: test/motorcycle_s_001164.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_001164.png
# upload: test/motorcycle_s_001519.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_001519.png
# upload: test/motorcycle_s_000878.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_000878.png
# upload: test/motorcycle_s_001508.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_001508.png
# upload: test/motorcycle_s_001348.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_001348.png
# upload: test/motorcycle_s_001249.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_001249.png
# upload: test/motorcycle_s_001687.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_001687.png
# upload: test/motorcycle_s_001782.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_001782.png
# upload: test/motorcycle_s_001892.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_001892.png
# upload: test/motorcycle_s_001385.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_001385.png
# upload: test/motorcycle_s_001679.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_001679.png
# upload: test/motorcycle_s_002026.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_002026.png
# upload: test/motorcycle_s_001906.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_001906.png
# upload: test/motorcycle_s_001971.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_001971.png
# upload: test/motorcycle_s_002112.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_002112.png
# upload: test/motorcycle_s_002126.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_002126.png
# upload: test/motorcycle_s_001936.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_001936.png
# upload: test/motorcycle_s_002177.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_002177.png
# upload: test/motorcycle_s_001960.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_001960.png
# upload: test/motorcycle_s_001955.png to s3://sagemaker-us-east-1-072298625118/test/motorcycle_s_001955.png
# upload: test/ordinary_bicycle_s_000158.png to s3://sagemaker-us-east-1-072298625118/test/ordinary_bicycle_s_000158.png
# upload: test/ordinary_bicycle_s_000284.png to s3://sagemaker-us-east-1-072298625118/test/ordinary_bicycle_s_000284.png
# upload: test/ordinary_bicycle_s_000105.png to s3://sagemaker-us-east-1-072298625118/test/ordinary_bicycle_s_000105.png
# upload: test/ordinary_bicycle_s_000437.png to s3://sagemaker-us-east-1-072298625118/test/ordinary_bicycle_s_000437.png
# upload: test/ordinary_bicycle_s_000431.png to s3://sagemaker-us-east-1-072298625118/test/ordinary_bicycle_s_000431.png
# upload: test/safety_bicycle_s_000235.png to s3://sagemaker-us-east-1-072298625118/test/safety_bicycle_s_000235.png
# upload: test/safety_bicycle_s_000315.png to s3://sagemaker-us-east-1-072298625118/test/safety_bicycle_s_000315.png
# upload: test/safety_bicycle_s_000280.png to s3://sagemaker-us-east-1-072298625118/test/safety_bicycle_s_000280.png
# upload: test/safety_bicycle_s_001286.png to s3://sagemaker-us-east-1-072298625118/test/safety_bicycle_s_001286.png
# upload: test/ordinary_bicycle_s_000113.png to s3://sagemaker-us-east-1-072298625118/test/ordinary_bicycle_s_000113.png
# upload: test/safety_bicycle_s_001575.png to s3://sagemaker-us-east-1-072298625118/test/safety_bicycle_s_001575.png
# upload: test/ordinary_bicycle_s_000169.png to s3://sagemaker-us-east-1-072298625118/test/ordinary_bicycle_s_000169.png
# upload: test/minibike_s_002051.png to s3://sagemaker-us-east-1-072298625118/test/minibike_s_002051.png
# upload: test/safety_bike_s_000390.png to s3://sagemaker-us-east-1-072298625118/test/safety_bike_s_000390.png
# upload: test/safety_bicycle_s_001153.png to s3://sagemaker-us-east-1-072298625118/test/safety_bicycle_s_001153.png
# upload: test/safety_bike_s_000540.png to s3://sagemaker-us-east-1-072298625118/test/safety_bike_s_000540.png
# upload: test/safety_bike_s_000192.png to s3://sagemaker-us-east-1-072298625118/test/safety_bike_s_000192.png
# upload: test/safety_bike_s_000438.png to s3://sagemaker-us-east-1-072298625118/test/safety_bike_s_000438.png
# upload: test/safety_bike_s_000791.png to s3://sagemaker-us-east-1-072298625118/test/safety_bike_s_000791.png
# upload: test/safety_bicycle_s_001322.png to s3://sagemaker-us-east-1-072298625118/test/safety_bicycle_s_001322.png
# upload: test/safety_bike_s_000541.png to s3://sagemaker-us-east-1-072298625118/test/safety_bike_s_000541.png
# upload: test/safety_bike_s_000488.png to s3://sagemaker-us-east-1-072298625118/test/safety_bike_s_000488.png
# upload: test/safety_bike_s_000699.png to s3://sagemaker-us-east-1-072298625118/test/safety_bike_s_000699.png
# upload: test/ordinary_bicycle_s_000350.png to s3://sagemaker-us-east-1-072298625118/test/ordinary_bicycle_s_000350.png
# upload: test/safety_bike_s_001088.png to s3://sagemaker-us-east-1-072298625118/test/safety_bike_s_001088.png
# upload: test/safety_bike_s_001132.png to s3://sagemaker-us-east-1-072298625118/test/safety_bike_s_001132.png
# upload: test/safety_bike_s_001481.png to s3://sagemaker-us-east-1-072298625118/test/safety_bike_s_001481.png
# upload: test/trail_bike_s_000073.png to s3://sagemaker-us-east-1-072298625118/test/trail_bike_s_000073.png
# upload: test/velocipede_s_000001.png to s3://sagemaker-us-east-1-072298625118/test/velocipede_s_000001.png
# upload: test/safety_bike_s_001253.png to s3://sagemaker-us-east-1-072298625118/test/safety_bike_s_001253.png
# upload: test/velocipede_s_000041.png to s3://sagemaker-us-east-1-072298625118/test/velocipede_s_000041.png
# upload: test/velocipede_s_000292.png to s3://sagemaker-us-east-1-072298625118/test/velocipede_s_000292.png
# upload: test/safety_bike_s_001690.png to s3://sagemaker-us-east-1-072298625118/test/safety_bike_s_001690.png
# upload: test/safety_bike_s_001087.png to s3://sagemaker-us-east-1-072298625118/test/safety_bike_s_001087.png
# upload: test/velocipede_s_000106.png to s3://sagemaker-us-east-1-072298625118/test/velocipede_s_000106.png
# upload: test/velocipede_s_001335.png to s3://sagemaker-us-east-1-072298625118/test/velocipede_s_001335.png
# upload: test/velocipede_s_001277.png to s3://sagemaker-us-east-1-072298625118/test/velocipede_s_001277.png
# upload: test/velocipede_s_001355.png to s3://sagemaker-us-east-1-072298625118/test/velocipede_s_001355.png
# upload: test/safety_bike_s_001065.png to s3://sagemaker-us-east-1-072298625118/test/safety_bike_s_001065.png
# upload: test/velocipede_s_001232.png to s3://sagemaker-us-east-1-072298625118/test/velocipede_s_001232.png
# upload: test/velocipede_s_000863.png to s3://sagemaker-us-east-1-072298625118/test/velocipede_s_000863.png
# upload: test/velocipede_s_001466.png to s3://sagemaker-us-east-1-072298625118/test/velocipede_s_001466.png
# upload: test/velocipede_s_001633.png to s3://sagemaker-us-east-1-072298625118/test/velocipede_s_001633.png
# upload: test/velocipede_s_001699.png to s3://sagemaker-us-east-1-072298625118/test/velocipede_s_001699.png
# upload: test/velocipede_s_001379.png to s3://sagemaker-us-east-1-072298625118/test/velocipede_s_001379.png
# upload: test/velocipede_s_000369.png to s3://sagemaker-us-east-1-072298625118/test/velocipede_s_000369.png
# upload: test/velocipede_s_001790.png to s3://sagemaker-us-east-1-072298625118/test/velocipede_s_001790.png
# upload: test/velocipede_s_001201.png to s3://sagemaker-us-east-1-072298625118/test/velocipede_s_001201.png
# upload: test/velocipede_s_001744.png to s3://sagemaker-us-east-1-072298625118/test/velocipede_s_001744.png

# %% [markdown]
# And that's it! You can check the bucket and verify that the items were uploaded.
#
# ## Model Training
#
# For Image Classification, Sagemaker [also expects metadata](https://docs.aws.amazon.com/sagemaker/latest/dg/image-classification.html) e.g. in the form of TSV files with labels and filepaths. We can generate these using our Pandas DataFrames from earlier:

# %%
def to_metadata_file(df, prefix):
    df["s3_path"] = df["filenames"]
    df["labels"] = df["labels"].apply(lambda x: 0 if x==8 else 1)
    return df[["row", "labels", "s3_path"]].to_csv(
        f"{prefix}.lst", sep="\t", index=False, header=False
    )
    
to_metadata_file(df_train.copy(), "train")
to_metadata_file(df_test.copy(), "test")

# %% [markdown]
# We can also upload our manifest files:

# %%
import boto3

# Upload files
boto3.Session().resource('s3').Bucket(
    bucket).Object('train.lst').upload_file('./train.lst')
boto3.Session().resource('s3').Bucket(
    bucket).Object('test.lst').upload_file('./test.lst')

# %% [markdown]
# Using the `bucket` and `region` info we can get the latest prebuilt container to run our training job, and define an output location on our s3 bucket for the model. Use the `image_uris` function from the SageMaker SDK to retrieve the latest `image-classification` image below:

# %%
# Use the image_uris function to retrieve the latest 'image-classification' image 
algo_image = sagemaker.image_uris.retrieve(
    framework='image-classification',
    region=region
)
s3_output_location = f"s3://{bucket}/models/image_model"

print(f"{algo_image=}")
print(f"{s3_output_location=}")
# Out:
# algo_image='811284229777.dkr.ecr.us-east-1.amazonaws.com/image-classification:1'
# s3_output_location='s3://sagemaker-us-east-1-072298625118/models/image_model'

# %% [markdown]
# We're ready to create an estimator! Create an estimator `img_classifier_model` that uses one instance of `ml.p3.2xlarge`. Ensure that y ou use the output location we defined above - we'll be referring to that later!

# %%
img_classifier_model=sagemaker.estimator.Estimator(
    image_uri=algo_image,
    role=role,
    instance_count=1,
    instance_type='ml.p3.2xlarge',
    output_path=s3_output_location,
    sagemaker_session=sagemaker.Session()
)

# %% [markdown]
# We can also set a few key hyperparameters and define the inputs for our model:

# %%
# Set the hyperparameters for the model
img_classifier_model.set_hyperparameters(
    image_shape="3,32,32",          # For CIFAR-100: 3 channels (RGB) and 32x32 pixels
    num_classes=2,                  # CIFAR-100 has 100 classes
    num_training_samples=10000      # CIFAR-100 has 50,000 training samples (I tried 50_000, it was insainly slow)
)

# %% [markdown]
# The `image-classification` image uses four input channels with very specific input parameters. For convenience, we've provided them below:

# %%
from sagemaker.debugger import Rule, rule_configs
from sagemaker.session import TrainingInput
model_inputs = {
        "train": sagemaker.inputs.TrainingInput(
            s3_data=f"s3://{bucket}/train/",
            content_type="application/x-image"
        ),
        "validation": sagemaker.inputs.TrainingInput(
            s3_data=f"s3://{bucket}/test/",
            content_type="application/x-image"
        ),
        "train_lst": sagemaker.inputs.TrainingInput(
            s3_data=f"s3://{bucket}/train.lst",
            content_type="application/x-image"
        ),
        "validation_lst": sagemaker.inputs.TrainingInput(
            s3_data=f"s3://{bucket}/test.lst",
            content_type="application/x-image"
        )
}

# %% [markdown]
# Great, now we can train the model using the model_inputs. In the cell below, call the `fit` method on our model,:

# %%
## TODO: train your model
img_classifier_model.fit(inputs=model_inputs)
print("Model training started")
# Out:
# INFO:sagemaker:Creating training-job with name: image-classification-2024-10-06-15-48-41-675
# 2024-10-06 15:48:41 Starting - Starting the training job...
# 2024-10-06 15:48:55 Pending - Training job waiting for capacity...
# 2024-10-06 15:49:21 Pending - Preparing the instances for training...
# 2024-10-06 15:50:03 Downloading - Downloading input data...
# 2024-10-06 15:50:24 Downloading - Downloading the training image.....................
# 2024-10-06 15:54:06 Training - Training image download completed. Training in progress...Docker entrypoint called with argument(s): train
# Running default environment configuration script
# Nvidia gpu devices, drivers and cuda toolkit versions (only available on hosts with GPU):
# Sun Oct  6 15:54:28 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.90.07              Driver Version: 550.90.07      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla V100-SXM2-16GB           On  |   00000000:00:1E.0 Off |                    0 |
# | N/A   33C    P0             23W /  300W |       1MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Checking for nvidia driver and cuda compatibility.
# CUDA Compatibility driver provided.
# Proceeding with compatibility check between driver, cuda-toolkit and cuda-compat.
# Detected cuda-toolkit version: 11.1.
# Detected cuda-compat version: 455.32.00.
# Detected Nvidia driver version: 550.90.07.
# Nvidia driver compatible with cuda-toolkit. Disabling cuda-compat.
# /opt/amazon/lib/python3.8/site-packages/mxnet/model.py:97: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if num_device is 1 and 'dist' not in kvstore:
# [10/06/2024 15:54:31 INFO 140464643696448] Reading default configuration from /opt/amazon/lib/python3.8/site-packages/image_classification/default-input.json: {'use_pretrained_model': 0, 'num_layers': 152, 'epochs': 30, 'learning_rate': 0.1, 'lr_scheduler_factor': 0.1, 'optimizer': 'sgd', 'momentum': 0, 'weight_decay': 0.0001, 'beta_1': 0.9, 'beta_2': 0.999, 'eps': 1e-08, 'gamma': 0.9, 'mini_batch_size': 32, 'image_shape': '3,224,224', 'precision_dtype': 'float32'}
# [10/06/2024 15:54:31 INFO 140464643696448] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'image_shape': '3,32,32', 'num_classes': '2', 'num_training_samples': '10000'}
# [10/06/2024 15:54:31 INFO 140464643696448] Final configuration: {'use_pretrained_model': 0, 'num_layers': 152, 'epochs': 30, 'learning_rate': 0.1, 'lr_scheduler_factor': 0.1, 'optimizer': 'sgd', 'momentum': 0, 'weight_decay': 0.0001, 'beta_1': 0.9, 'beta_2': 0.999, 'eps': 1e-08, 'gamma': 0.9, 'mini_batch_size': 32, 'image_shape': '3,32,32', 'precision_dtype': 'float32', 'num_classes': '2', 'num_training_samples': '10000'}
# [10/06/2024 15:54:31 INFO 140464643696448] Searching for .lst files in /opt/ml/input/data/train_lst.
# [10/06/2024 15:54:31 INFO 140464643696448] Creating record files for train.lst
# [10/06/2024 15:54:32 INFO 140464643696448] Done creating record files...
# [10/06/2024 15:54:32 INFO 140464643696448] Searching for .lst files in /opt/ml/input/data/validation_lst.
# [10/06/2024 15:54:32 INFO 140464643696448] Creating record files for test.lst
# [10/06/2024 15:54:32 INFO 140464643696448] Done creating record files...
# [10/06/2024 15:54:32 INFO 140464643696448] use_pretrained_model: 0
# [10/06/2024 15:54:32 INFO 140464643696448] multi_label: 0
# [10/06/2024 15:54:32 INFO 140464643696448] Performing random weight initialization
# [10/06/2024 15:54:32 INFO 140464643696448] ---- Parameters ----
# [10/06/2024 15:54:32 INFO 140464643696448] num_layers: 152
# [10/06/2024 15:54:32 INFO 140464643696448] data type: <class 'numpy.float32'>
# [10/06/2024 15:54:32 INFO 140464643696448] epochs: 30
# [10/06/2024 15:54:32 INFO 140464643696448] optimizer: sgd
# [10/06/2024 15:54:32 INFO 140464643696448] momentum: 0.9
# [10/06/2024 15:54:32 INFO 140464643696448] weight_decay: 0.0001
# [10/06/2024 15:54:32 INFO 140464643696448] learning_rate: 0.1
# [10/06/2024 15:54:32 INFO 140464643696448] num_training_samples: 10000
# [10/06/2024 15:54:32 INFO 140464643696448] mini_batch_size: 32
# [10/06/2024 15:54:32 INFO 140464643696448] image_shape: 3,32,32
# [10/06/2024 15:54:32 INFO 140464643696448] num_classes: 2
# [10/06/2024 15:54:32 INFO 140464643696448] augmentation_type: None
# [10/06/2024 15:54:32 INFO 140464643696448] kv_store: device
# [10/06/2024 15:54:32 INFO 140464643696448] checkpoint_frequency not set, will store the best model
# [10/06/2024 15:54:32 INFO 140464643696448] --------------------
# /opt/amazon/python3.8/lib/python3.8/subprocess.py:848: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdout = io.open(c2pread, 'rb', bufsize)
# [10/06/2024 15:54:32 INFO 140464643696448] Setting number of threads: 7
# [15:54:36] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_11.1.x.441.0/AL2_x86_64/generic-flavor/src/src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (setting env variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [10/06/2024 15:54:41 INFO 140464643696448] Epoch[0] Batch [20]#011Speed: 123.804 samples/sec#011accuracy=0.558036
# [10/06/2024 15:54:44 INFO 140464643696448] Epoch[0] Batch [40]#011Speed: 152.406 samples/sec#011accuracy=0.592226
# [10/06/2024 15:54:48 INFO 140464643696448] Epoch[0] Batch [60]#011Speed: 164.354 samples/sec#011accuracy=0.633709
# [10/06/2024 15:54:51 INFO 140464643696448] Epoch[0] Batch [80]#011Speed: 171.411 samples/sec#011accuracy=0.643519
# [10/06/2024 15:54:54 INFO 140464643696448] Epoch[0] Batch [100]#011Speed: 175.948 samples/sec#011accuracy=0.643564
# [10/06/2024 15:54:57 INFO 140464643696448] Epoch[0] Batch [120]#011Speed: 179.334 samples/sec#011accuracy=0.660382
# [10/06/2024 15:55:01 INFO 140464643696448] Epoch[0] Batch [140]#011Speed: 181.674 samples/sec#011accuracy=0.677748
# [10/06/2024 15:55:04 INFO 140464643696448] Epoch[0] Batch [160]#011Speed: 182.508 samples/sec#011accuracy=0.692741
# [10/06/2024 15:55:07 INFO 140464643696448] Epoch[0] Batch [180]#011Speed: 183.956 samples/sec#011accuracy=0.702175
# [10/06/2024 15:55:11 INFO 140464643696448] Epoch[0] Batch [200]#011Speed: 185.243 samples/sec#011accuracy=0.711287
# [10/06/2024 15:55:14 INFO 140464643696448] Epoch[0] Batch [220]#011Speed: 186.212 samples/sec#011accuracy=0.718043
# [10/06/2024 15:55:17 INFO 140464643696448] Epoch[0] Batch [240]#011Speed: 187.144 samples/sec#011accuracy=0.725752
# [10/06/2024 15:55:20 INFO 140464643696448] Epoch[0] Batch [260]#011Speed: 187.804 samples/sec#011accuracy=0.732878
# [10/06/2024 15:55:24 INFO 140464643696448] Epoch[0] Batch [280]#011Speed: 188.376 samples/sec#011accuracy=0.739101
# [10/06/2024 15:55:27 INFO 140464643696448] Epoch[0] Batch [300]#011Speed: 188.920 samples/sec#011accuracy=0.744601
# [10/06/2024 15:55:29 INFO 140464643696448] Epoch[0] Train-accuracy=0.747796
# [10/06/2024 15:55:29 INFO 140464643696448] Epoch[0] Time cost=52.615
# [10/06/2024 15:55:29 INFO 140464643696448] Epoch[0] Validation-accuracy=0.791667
# [10/06/2024 15:55:29 INFO 140464643696448] Storing the best model with validation accuracy: 0.791667
# [10/06/2024 15:55:30 INFO 140464643696448] Saved checkpoint to "/opt/ml/model/image-classification-0001.params"
# [10/06/2024 15:55:33 INFO 140464643696448] Epoch[1] Batch [20]#011Speed: 188.197 samples/sec#011accuracy=0.849702
# [10/06/2024 15:55:36 INFO 140464643696448] Epoch[1] Batch [40]#011Speed: 192.250 samples/sec#011accuracy=0.849848
# [10/06/2024 15:55:40 INFO 140464643696448] Epoch[1] Batch [60]#011Speed: 194.025 samples/sec#011accuracy=0.847848
# [10/06/2024 15:55:43 INFO 140464643696448] Epoch[1] Batch [80]#011Speed: 194.927 samples/sec#011accuracy=0.852238
# [10/06/2024 15:55:46 INFO 140464643696448] Epoch[1] Batch [100]#011Speed: 195.234 samples/sec#011accuracy=0.857983
# [10/06/2024 15:55:49 INFO 140464643696448] Epoch[1] Batch [120]#011Speed: 195.237 samples/sec#011accuracy=0.857696
# [10/06/2024 15:55:53 INFO 140464643696448] Epoch[1] Batch [140]#011Speed: 195.428 samples/sec#011accuracy=0.862810
# [10/06/2024 15:55:56 INFO 140464643696448] Epoch[1] Batch [160]#011Speed: 195.568 samples/sec#011accuracy=0.863548
# [10/06/2024 15:55:59 INFO 140464643696448] Epoch[1] Batch [180]#011Speed: 195.834 samples/sec#011accuracy=0.862742
# [10/06/2024 15:56:02 INFO 140464643696448] Epoch[1] Batch [200]#011Speed: 195.398 samples/sec#011accuracy=0.866604
# [10/06/2024 15:56:06 INFO 140464643696448] Epoch[1] Batch [220]#011Speed: 195.420 samples/sec#011accuracy=0.868071
# [10/06/2024 15:56:09 INFO 140464643696448] Epoch[1] Batch [240]#011Speed: 195.419 samples/sec#011accuracy=0.871629
# [10/06/2024 15:56:12 INFO 140464643696448] Epoch[1] Batch [260]#011Speed: 195.573 samples/sec#011accuracy=0.873683
# [10/06/2024 15:56:15 INFO 140464643696448] Epoch[1] Batch [280]#011Speed: 195.685 samples/sec#011accuracy=0.875556
# [10/06/2024 15:56:19 INFO 140464643696448] Epoch[1] Batch [300]#011Speed: 195.767 samples/sec#011accuracy=0.879153
# [10/06/2024 15:56:21 INFO 140464643696448] Epoch[1] Train-accuracy=0.880709
# [10/06/2024 15:56:21 INFO 140464643696448] Epoch[1] Time cost=50.808
# [10/06/2024 15:56:21 INFO 140464643696448] Epoch[1] Validation-accuracy=0.833333
# [10/06/2024 15:56:21 INFO 140464643696448] Storing the best model with validation accuracy: 0.833333
# [10/06/2024 15:56:22 INFO 140464643696448] Saved checkpoint to "/opt/ml/model/image-classification-0002.params"
# [10/06/2024 15:56:25 INFO 140464643696448] Epoch[2] Batch [20]#011Speed: 191.127 samples/sec#011accuracy=0.934524
# [10/06/2024 15:56:28 INFO 140464643696448] Epoch[2] Batch [40]#011Speed: 194.493 samples/sec#011accuracy=0.925305
# [10/06/2024 15:56:32 INFO 140464643696448] Epoch[2] Batch [60]#011Speed: 195.063 samples/sec#011accuracy=0.923668
# [10/06/2024 15:56:35 INFO 140464643696448] Epoch[2] Batch [80]#011Speed: 195.659 samples/sec#011accuracy=0.930556
# [10/06/2024 15:56:38 INFO 140464643696448] Epoch[2] Batch [100]#011Speed: 195.801 samples/sec#011accuracy=0.931931
# [10/06/2024 15:56:41 INFO 140464643696448] Epoch[2] Batch [120]#011Speed: 195.981 samples/sec#011accuracy=0.935434
# [10/06/2024 15:56:45 INFO 140464643696448] Epoch[2] Batch [140]#011Speed: 196.164 samples/sec#011accuracy=0.938165
# [10/06/2024 15:56:48 INFO 140464643696448] Epoch[2] Batch [160]#011Speed: 196.249 samples/sec#011accuracy=0.942935
# [10/06/2024 15:56:51 INFO 140464643696448] Epoch[2] Batch [180]#011Speed: 196.095 samples/sec#011accuracy=0.943198
# [10/06/2024 15:56:54 INFO 140464643696448] Epoch[2] Batch [200]#011Speed: 196.210 samples/sec#011accuracy=0.941698
# [10/06/2024 15:56:58 INFO 140464643696448] Epoch[2] Batch [220]#011Speed: 196.317 samples/sec#011accuracy=0.942873
# [10/06/2024 15:57:01 INFO 140464643696448] Epoch[2] Batch [240]#011Speed: 196.305 samples/sec#011accuracy=0.946317
# [10/06/2024 15:57:04 INFO 140464643696448] Epoch[2] Batch [260]#011Speed: 195.899 samples/sec#011accuracy=0.948755
# [10/06/2024 15:57:07 INFO 140464643696448] Epoch[2] Batch [280]#011Speed: 195.970 samples/sec#011accuracy=0.950845
# [10/06/2024 15:57:11 INFO 140464643696448] Epoch[2] Batch [300]#011Speed: 196.107 samples/sec#011accuracy=0.952554
# [10/06/2024 15:57:12 INFO 140464643696448] Epoch[2] Train-accuracy=0.953125
# [10/06/2024 15:57:12 INFO 140464643696448] Epoch[2] Time cost=50.746
# [10/06/2024 15:57:13 INFO 140464643696448] Epoch[2] Validation-accuracy=0.812500
# [10/06/2024 15:57:17 INFO 140464643696448] Epoch[3] Batch [20]#011Speed: 193.845 samples/sec#011accuracy=0.979167
# [10/06/2024 15:57:20 INFO 140464643696448] Epoch[3] Batch [40]#011Speed: 195.306 samples/sec#011accuracy=0.969512
# [10/06/2024 15:57:23 INFO 140464643696448] Epoch[3] Batch [60]#011Speed: 195.464 samples/sec#011accuracy=0.972336
# [10/06/2024 15:57:26 INFO 140464643696448] Epoch[3] Batch [80]#011Speed: 195.279 samples/sec#011accuracy=0.975694
# [10/06/2024 15:57:30 INFO 140464643696448] Epoch[3] Batch [100]#011Speed: 195.894 samples/sec#011accuracy=0.975248
# [10/06/2024 15:57:33 INFO 140464643696448] Epoch[3] Batch [120]#011Speed: 195.854 samples/sec#011accuracy=0.971591
# [10/06/2024 15:57:36 INFO 140464643696448] Epoch[3] Batch [140]#011Speed: 196.111 samples/sec#011accuracy=0.972074
# [10/06/2024 15:57:39 INFO 140464643696448] Epoch[3] Batch [160]#011Speed: 196.266 samples/sec#011accuracy=0.974185
# [10/06/2024 15:57:43 INFO 140464643696448] Epoch[3] Batch [180]#011Speed: 195.995 samples/sec#011accuracy=0.976519
# [10/06/2024 15:57:46 INFO 140464643696448] Epoch[3] Batch [200]#011Speed: 195.965 samples/sec#011accuracy=0.977456
# [10/06/2024 15:57:51 INFO 140464643696448] Epoch[3] Batch [220]#011Speed: 189.520 samples/sec#011accuracy=0.976527
# [10/06/2024 15:57:54 INFO 140464643696448] Epoch[3] Batch [240]#011Speed: 189.234 samples/sec#011accuracy=0.976919
# [10/06/2024 15:57:57 INFO 140464643696448] Epoch[3] Batch [260]#011Speed: 189.899 samples/sec#011accuracy=0.977251
# [10/06/2024 15:58:00 INFO 140464643696448] Epoch[3] Batch [280]#011Speed: 190.468 samples/sec#011accuracy=0.978092
# [10/06/2024 15:58:04 INFO 140464643696448] Epoch[3] Batch [300]#011Speed: 190.571 samples/sec#011accuracy=0.979340
# [10/06/2024 15:58:06 INFO 140464643696448] Epoch[3] Train-accuracy=0.979467
# [10/06/2024 15:58:06 INFO 140464643696448] Epoch[3] Time cost=52.152
# [10/06/2024 15:58:06 INFO 140464643696448] Epoch[3] Validation-accuracy=0.821429
# [10/06/2024 15:58:10 INFO 140464643696448] Epoch[4] Batch [20]#011Speed: 192.040 samples/sec#011accuracy=0.974702
# [10/06/2024 15:58:13 INFO 140464643696448] Epoch[4] Batch [40]#011Speed: 194.134 samples/sec#011accuracy=0.975610
# [10/06/2024 15:58:16 INFO 140464643696448] Epoch[4] Batch [60]#011Speed: 195.213 samples/sec#011accuracy=0.979508
# [10/06/2024 15:58:20 INFO 140464643696448] Epoch[4] Batch [80]#011Speed: 195.541 samples/sec#011accuracy=0.982639
# [10/06/2024 15:58:23 INFO 140464643696448] Epoch[4] Batch [100]#011Speed: 196.234 samples/sec#011accuracy=0.985149
# [10/06/2024 15:58:26 INFO 140464643696448] Epoch[4] Batch [120]#011Speed: 196.684 samples/sec#011accuracy=0.985795
# [10/06/2024 15:58:29 INFO 140464643696448] Epoch[4] Batch [140]#011Speed: 196.821 samples/sec#011accuracy=0.986037
# [10/06/2024 15:58:32 INFO 140464643696448] Epoch[4] Batch [160]#011Speed: 196.727 samples/sec#011accuracy=0.985637
# [10/06/2024 15:58:36 INFO 140464643696448] Epoch[4] Batch [180]#011Speed: 196.534 samples/sec#011accuracy=0.986015
# [10/06/2024 15:58:39 INFO 140464643696448] Epoch[4] Batch [200]#011Speed: 196.684 samples/sec#011accuracy=0.985541
# [10/06/2024 15:58:42 INFO 140464643696448] Epoch[4] Batch [220]#011Speed: 196.807 samples/sec#011accuracy=0.986708
# [10/06/2024 15:58:45 INFO 140464643696448] Epoch[4] Batch [240]#011Speed: 196.768 samples/sec#011accuracy=0.987033
# [10/06/2024 15:58:49 INFO 140464643696448] Epoch[4] Batch [260]#011Speed: 196.854 samples/sec#011accuracy=0.987668
# [10/06/2024 15:58:52 INFO 140464643696448] Epoch[4] Batch [280]#011Speed: 196.828 samples/sec#011accuracy=0.987322
# [10/06/2024 15:58:55 INFO 140464643696448] Epoch[4] Batch [300]#011Speed: 196.928 samples/sec#011accuracy=0.987126
# [10/06/2024 15:58:57 INFO 140464643696448] Epoch[4] Train-accuracy=0.987580
# [10/06/2024 15:58:57 INFO 140464643696448] Epoch[4] Time cost=50.533
# [10/06/2024 15:58:57 INFO 140464643696448] Epoch[4] Validation-accuracy=0.848958
# [10/06/2024 15:58:58 INFO 140464643696448] Storing the best model with validation accuracy: 0.848958
# [10/06/2024 15:58:58 INFO 140464643696448] Saved checkpoint to "/opt/ml/model/image-classification-0005.params"
# [10/06/2024 15:59:01 INFO 140464643696448] Epoch[5] Batch [20]#011Speed: 192.572 samples/sec#011accuracy=0.997024
# [10/06/2024 15:59:05 INFO 140464643696448] Epoch[5] Batch [40]#011Speed: 193.018 samples/sec#011accuracy=0.991616
# [10/06/2024 15:59:08 INFO 140464643696448] Epoch[5] Batch [60]#011Speed: 194.501 samples/sec#011accuracy=0.992828
# [10/06/2024 15:59:11 INFO 140464643696448] Epoch[5] Batch [80]#011Speed: 194.941 samples/sec#011accuracy=0.994599
# [10/06/2024 15:59:15 INFO 140464643696448] Epoch[5] Batch [100]#011Speed: 195.386 samples/sec#011accuracy=0.995050
# [10/06/2024 15:59:18 INFO 140464643696448] Epoch[5] Batch [120]#011Speed: 195.682 samples/sec#011accuracy=0.995351
# [10/06/2024 15:59:21 INFO 140464643696448] Epoch[5] Batch [140]#011Speed: 196.053 samples/sec#011accuracy=0.994681
# [10/06/2024 15:59:24 INFO 140464643696448] Epoch[5] Batch [160]#011Speed: 196.291 samples/sec#011accuracy=0.993012
# [10/06/2024 15:59:27 INFO 140464643696448] Epoch[5] Batch [180]#011Speed: 196.471 samples/sec#011accuracy=0.990849
# [10/06/2024 15:59:31 INFO 140464643696448] Epoch[5] Batch [200]#011Speed: 196.313 samples/sec#011accuracy=0.991294
# [10/06/2024 15:59:34 INFO 140464643696448] Epoch[5] Batch [220]#011Speed: 196.405 samples/sec#011accuracy=0.991092
# [10/06/2024 15:59:37 INFO 140464643696448] Epoch[5] Batch [240]#011Speed: 196.367 samples/sec#011accuracy=0.990534
# [10/06/2024 15:59:41 INFO 140464643696448] Epoch[5] Batch [260]#011Speed: 196.239 samples/sec#011accuracy=0.990302
# [10/06/2024 15:59:44 INFO 140464643696448] Epoch[5] Batch [280]#011Speed: 196.395 samples/sec#011accuracy=0.990436
# [10/06/2024 15:59:47 INFO 140464643696448] Epoch[5] Batch [300]#011Speed: 196.470 samples/sec#011accuracy=0.990449
# [10/06/2024 15:59:49 INFO 140464643696448] Epoch[5] Train-accuracy=0.990585
# [10/06/2024 15:59:49 INFO 140464643696448] Epoch[5] Time cost=50.644
# [10/06/2024 15:59:49 INFO 140464643696448] Epoch[5] Validation-accuracy=0.796875
# [10/06/2024 15:59:53 INFO 140464643696448] Epoch[6] Batch [20]#011Speed: 193.057 samples/sec#011accuracy=0.992560
# [10/06/2024 15:59:56 INFO 140464643696448] Epoch[6] Batch [40]#011Speed: 195.945 samples/sec#011accuracy=0.994665
# [10/06/2024 15:59:59 INFO 140464643696448] Epoch[6] Batch [60]#011Speed: 196.991 samples/sec#011accuracy=0.995902
# [10/06/2024 16:00:03 INFO 140464643696448] Epoch[6] Batch [80]#011Speed: 195.966 samples/sec#011accuracy=0.996914
# [10/06/2024 16:00:06 INFO 140464643696448] Epoch[6] Batch [100]#011Speed: 195.657 samples/sec#011accuracy=0.997525
# [10/06/2024 16:00:09 INFO 140464643696448] Epoch[6] Batch [120]#011Speed: 196.056 samples/sec#011accuracy=0.997159
# [10/06/2024 16:00:13 INFO 140464643696448] Epoch[6] Batch [140]#011Speed: 196.060 samples/sec#011accuracy=0.997562
# [10/06/2024 16:00:16 INFO 140464643696448] Epoch[6] Batch [160]#011Speed: 195.962 samples/sec#011accuracy=0.997477
# [10/06/2024 16:00:19 INFO 140464643696448] Epoch[6] Batch [180]#011Speed: 196.234 samples/sec#011accuracy=0.997410
# [10/06/2024 16:00:22 INFO 140464643696448] Epoch[6] Batch [200]#011Speed: 196.517 samples/sec#011accuracy=0.997668
# [10/06/2024 16:00:25 INFO 140464643696448] Epoch[6] Batch [220]#011Speed: 196.722 samples/sec#011accuracy=0.997455
# [10/06/2024 16:00:29 INFO 140464643696448] Epoch[6] Batch [240]#011Speed: 196.747 samples/sec#011accuracy=0.996499
# [10/06/2024 16:00:32 INFO 140464643696448] Epoch[6] Batch [260]#011Speed: 196.873 samples/sec#011accuracy=0.995809
# [10/06/2024 16:00:35 INFO 140464643696448] Epoch[6] Batch [280]#011Speed: 196.807 samples/sec#011accuracy=0.995440
# [10/06/2024 16:00:38 INFO 140464643696448] Epoch[6] Batch [300]#011Speed: 196.930 samples/sec#011accuracy=0.995536
# [10/06/2024 16:00:40 INFO 140464643696448] Epoch[6] Train-accuracy=0.995593
# [10/06/2024 16:00:40 INFO 140464643696448] Epoch[6] Time cost=50.525
# [10/06/2024 16:00:41 INFO 140464643696448] Epoch[6] Validation-accuracy=0.859375
# [10/06/2024 16:00:41 INFO 140464643696448] Storing the best model with validation accuracy: 0.859375
# [10/06/2024 16:00:41 INFO 140464643696448] Saved checkpoint to "/opt/ml/model/image-classification-0007.params"
# [10/06/2024 16:00:45 INFO 140464643696448] Epoch[7] Batch [20]#011Speed: 193.237 samples/sec#011accuracy=0.994048
# [10/06/2024 16:00:48 INFO 140464643696448] Epoch[7] Batch [40]#011Speed: 194.941 samples/sec#011accuracy=0.996189
# [10/06/2024 16:00:51 INFO 140464643696448] Epoch[7] Batch [60]#011Speed: 195.634 samples/sec#011accuracy=0.996926
# [10/06/2024 16:00:54 INFO 140464643696448] Epoch[7] Batch [80]#011Speed: 195.771 samples/sec#011accuracy=0.997685
# [10/06/2024 16:00:58 INFO 140464643696448] Epoch[7] Batch [100]#011Speed: 196.124 samples/sec#011accuracy=0.998144
# [10/06/2024 16:01:01 INFO 140464643696448] Epoch[7] Batch [120]#011Speed: 196.122 samples/sec#011accuracy=0.998450
# [10/06/2024 16:01:04 INFO 140464643696448] Epoch[7] Batch [140]#011Speed: 195.241 samples/sec#011accuracy=0.998449
# [10/06/2024 16:01:08 INFO 140464643696448] Epoch[7] Batch [160]#011Speed: 195.431 samples/sec#011accuracy=0.998641
# [10/06/2024 16:01:11 INFO 140464643696448] Epoch[7] Batch [180]#011Speed: 195.542 samples/sec#011accuracy=0.998791
# [10/06/2024 16:01:14 INFO 140464643696448] Epoch[7] Batch [200]#011Speed: 195.694 samples/sec#011accuracy=0.998912
# [10/06/2024 16:01:17 INFO 140464643696448] Epoch[7] Batch [220]#011Speed: 195.812 samples/sec#011accuracy=0.999010
# [10/06/2024 16:01:21 INFO 140464643696448] Epoch[7] Batch [240]#011Speed: 195.956 samples/sec#011accuracy=0.999092
# [10/06/2024 16:01:24 INFO 140464643696448] Epoch[7] Batch [260]#011Speed: 196.188 samples/sec#011accuracy=0.999162
# [10/06/2024 16:01:27 INFO 140464643696448] Epoch[7] Batch [280]#011Speed: 196.301 samples/sec#011accuracy=0.999222
# [10/06/2024 16:01:30 INFO 140464643696448] Epoch[7] Batch [300]#011Speed: 196.393 samples/sec#011accuracy=0.999066
# [10/06/2024 16:01:32 INFO 140464643696448] Epoch[7] Train-accuracy=0.998898
# [10/06/2024 16:01:32 INFO 140464643696448] Epoch[7] Time cost=50.660
# [10/06/2024 16:01:33 INFO 140464643696448] Epoch[7] Validation-accuracy=0.834821
# [10/06/2024 16:01:36 INFO 140464643696448] Epoch[8] Batch [20]#011Speed: 193.748 samples/sec#011accuracy=0.997024
# [10/06/2024 16:01:40 INFO 140464643696448] Epoch[8] Batch [40]#011Speed: 195.837 samples/sec#011accuracy=0.992378
# [10/06/2024 16:01:43 INFO 140464643696448] Epoch[8] Batch [60]#011Speed: 196.210 samples/sec#011accuracy=0.991291
# [10/06/2024 16:01:46 INFO 140464643696448] Epoch[8] Batch [80]#011Speed: 196.410 samples/sec#011accuracy=0.991512
# [10/06/2024 16:01:49 INFO 140464643696448] Epoch[8] Batch [100]#011Speed: 196.446 samples/sec#011accuracy=0.992884
# [10/06/2024 16:01:53 INFO 140464643696448] Epoch[8] Batch [120]#011Speed: 196.561 samples/sec#011accuracy=0.991994
# [10/06/2024 16:01:56 INFO 140464643696448] Epoch[8] Batch [140]#011Speed: 196.816 samples/sec#011accuracy=0.992908
# [10/06/2024 16:01:59 INFO 140464643696448] Epoch[8] Batch [160]#011Speed: 196.952 samples/sec#011accuracy=0.992430
# [10/06/2024 16:02:02 INFO 140464643696448] Epoch[8] Batch [180]#011Speed: 196.690 samples/sec#011accuracy=0.993094
# [10/06/2024 16:02:06 INFO 140464643696448] Epoch[8] Batch [200]#011Speed: 196.571 samples/sec#011accuracy=0.993159
# [10/06/2024 16:02:09 INFO 140464643696448] Epoch[8] Batch [220]#011Speed: 196.620 samples/sec#011accuracy=0.993213
# [10/06/2024 16:02:12 INFO 140464643696448] Epoch[8] Batch [240]#011Speed: 196.627 samples/sec#011accuracy=0.991961
# [10/06/2024 16:02:15 INFO 140464643696448] Epoch[8] Batch [260]#011Speed: 196.773 samples/sec#011accuracy=0.990062
# [10/06/2024 16:02:19 INFO 140464643696448] Epoch[8] Batch [280]#011Speed: 196.759 samples/sec#011accuracy=0.989657
# [10/06/2024 16:02:22 INFO 140464643696448] Epoch[8] Batch [300]#011Speed: 196.873 samples/sec#011accuracy=0.990033
# [10/06/2024 16:02:24 INFO 140464643696448] Epoch[8] Train-accuracy=0.990284
# [10/06/2024 16:02:24 INFO 140464643696448] Epoch[8] Time cost=50.541
# [10/06/2024 16:02:24 INFO 140464643696448] Epoch[8] Validation-accuracy=0.848958
# [10/06/2024 16:02:28 INFO 140464643696448] Epoch[9] Batch [20]#011Speed: 195.328 samples/sec#011accuracy=0.998512
# [10/06/2024 16:02:31 INFO 140464643696448] Epoch[9] Batch [40]#011Speed: 195.667 samples/sec#011accuracy=0.995427
# [10/06/2024 16:02:34 INFO 140464643696448] Epoch[9] Batch [60]#011Speed: 196.275 samples/sec#011accuracy=0.996414
# [10/06/2024 16:02:38 INFO 140464643696448] Epoch[9] Batch [80]#011Speed: 196.296 samples/sec#011accuracy=0.997299
# [10/06/2024 16:02:41 INFO 140464643696448] Epoch[9] Batch [100]#011Speed: 196.700 samples/sec#011accuracy=0.997215
# [10/06/2024 16:02:44 INFO 140464643696448] Epoch[9] Batch [120]#011Speed: 196.933 samples/sec#011accuracy=0.996384
# [10/06/2024 16:02:47 INFO 140464643696448] Epoch[9] Batch [140]#011Speed: 197.050 samples/sec#011accuracy=0.995789
# [10/06/2024 16:02:50 INFO 140464643696448] Epoch[9] Batch [160]#011Speed: 197.227 samples/sec#011accuracy=0.995536
# [10/06/2024 16:02:54 INFO 140464643696448] Epoch[9] Batch [180]#011Speed: 197.395 samples/sec#011accuracy=0.995511
# [10/06/2024 16:02:57 INFO 140464643696448] Epoch[9] Batch [200]#011Speed: 197.526 samples/sec#011accuracy=0.995336
# [10/06/2024 16:03:00 INFO 140464643696448] Epoch[9] Batch [220]#011Speed: 197.546 samples/sec#011accuracy=0.995334
# [10/06/2024 16:03:04 INFO 140464643696448] Epoch[9] Batch [240]#011Speed: 196.986 samples/sec#011accuracy=0.994943
# [10/06/2024 16:03:07 INFO 140464643696448] Epoch[9] Batch [260]#011Speed: 197.079 samples/sec#011accuracy=0.995091
# [10/06/2024 16:03:10 INFO 140464643696448] Epoch[9] Batch [280]#011Speed: 197.189 samples/sec#011accuracy=0.995107
# [10/06/2024 16:03:13 INFO 140464643696448] Epoch[9] Batch [300]#011Speed: 197.267 samples/sec#011accuracy=0.994601
# [10/06/2024 16:03:15 INFO 140464643696448] Epoch[9] Train-accuracy=0.994591
# [10/06/2024 16:03:15 INFO 140464643696448] Epoch[9] Time cost=50.446
# [10/06/2024 16:03:15 INFO 140464643696448] Epoch[9] Validation-accuracy=0.848958
# [10/06/2024 16:03:19 INFO 140464643696448] Epoch[10] Batch [20]#011Speed: 192.156 samples/sec#011accuracy=0.995536
# [10/06/2024 16:03:22 INFO 140464643696448] Epoch[10] Batch [40]#011Speed: 194.963 samples/sec#011accuracy=0.993140
# [10/06/2024 16:03:26 INFO 140464643696448] Epoch[10] Batch [60]#011Speed: 195.940 samples/sec#011accuracy=0.994365
# [10/06/2024 16:03:29 INFO 140464643696448] Epoch[10] Batch [80]#011Speed: 196.298 samples/sec#011accuracy=0.995756
# [10/06/2024 16:03:32 INFO 140464643696448] Epoch[10] Batch [100]#011Speed: 196.542 samples/sec#011accuracy=0.996287
# [10/06/2024 16:03:35 INFO 140464643696448] Epoch[10] Batch [120]#011Speed: 196.973 samples/sec#011accuracy=0.996643
# [10/06/2024 16:03:39 INFO 140464643696448] Epoch[10] Batch [140]#011Speed: 197.149 samples/sec#011accuracy=0.996897
# [10/06/2024 16:03:42 INFO 140464643696448] Epoch[10] Batch [160]#011Speed: 196.910 samples/sec#011accuracy=0.997283
# [10/06/2024 16:03:45 INFO 140464643696448] Epoch[10] Batch [180]#011Speed: 196.929 samples/sec#011accuracy=0.997238
# [10/06/2024 16:03:48 INFO 140464643696448] Epoch[10] Batch [200]#011Speed: 197.215 samples/sec#011accuracy=0.997357
# [10/06/2024 16:03:52 INFO 140464643696448] Epoch[10] Batch [220]#011Speed: 197.206 samples/sec#011accuracy=0.996889
# [10/06/2024 16:03:55 INFO 140464643696448] Epoch[10] Batch [240]#011Speed: 197.273 samples/sec#011accuracy=0.997018
# [10/06/2024 16:03:58 INFO 140464643696448] Epoch[10] Batch [260]#011Speed: 197.331 samples/sec#011accuracy=0.996887
# [10/06/2024 16:04:01 INFO 140464643696448] Epoch[10] Batch [280]#011Speed: 197.275 samples/sec#011accuracy=0.996886
# [10/06/2024 16:04:05 INFO 140464643696448] Epoch[10] Batch [300]#011Speed: 196.901 samples/sec#011accuracy=0.996782
# [10/06/2024 16:04:06 INFO 140464643696448] Epoch[10] Train-accuracy=0.996895
# [10/06/2024 16:04:06 INFO 140464643696448] Epoch[10] Time cost=50.544
# [10/06/2024 16:04:07 INFO 140464643696448] Epoch[10] Validation-accuracy=0.828125
# [10/06/2024 16:04:11 INFO 140464643696448] Epoch[11] Batch [20]#011Speed: 193.841 samples/sec#011accuracy=1.000000
# [10/06/2024 16:04:14 INFO 140464643696448] Epoch[11] Batch [40]#011Speed: 196.211 samples/sec#011accuracy=1.000000
# [10/06/2024 16:04:17 INFO 140464643696448] Epoch[11] Batch [60]#011Speed: 197.334 samples/sec#011accuracy=0.999488
# [10/06/2024 16:04:20 INFO 140464643696448] Epoch[11] Batch [80]#011Speed: 197.004 samples/sec#011accuracy=0.999614
# [10/06/2024 16:04:24 INFO 140464643696448] Epoch[11] Batch [100]#011Speed: 197.261 samples/sec#011accuracy=0.999072
# [10/06/2024 16:04:27 INFO 140464643696448] Epoch[11] Batch [120]#011Speed: 197.302 samples/sec#011accuracy=0.998450
# [10/06/2024 16:04:30 INFO 140464643696448] Epoch[11] Batch [140]#011Speed: 197.274 samples/sec#011accuracy=0.998670
# [10/06/2024 16:04:33 INFO 140464643696448] Epoch[11] Batch [160]#011Speed: 197.292 samples/sec#011accuracy=0.998447
# [10/06/2024 16:04:37 INFO 140464643696448] Epoch[11] Batch [180]#011Speed: 197.472 samples/sec#011accuracy=0.998273
# [10/06/2024 16:04:40 INFO 140464643696448] Epoch[11] Batch [200]#011Speed: 197.294 samples/sec#011accuracy=0.998290
# [10/06/2024 16:04:43 INFO 140464643696448] Epoch[11] Batch [220]#011Speed: 197.398 samples/sec#011accuracy=0.998303
# [10/06/2024 16:04:46 INFO 140464643696448] Epoch[11] Batch [240]#011Speed: 197.413 samples/sec#011accuracy=0.998314
# [10/06/2024 16:04:50 INFO 140464643696448] Epoch[11] Batch [260]#011Speed: 197.383 samples/sec#011accuracy=0.998324
# [10/06/2024 16:04:53 INFO 140464643696448] Epoch[11] Batch [280]#011Speed: 197.482 samples/sec#011accuracy=0.998332
# [10/06/2024 16:04:56 INFO 140464643696448] Epoch[11] Batch [300]#011Speed: 197.626 samples/sec#011accuracy=0.998339
# [10/06/2024 16:04:58 INFO 140464643696448] Epoch[11] Train-accuracy=0.998197
# [10/06/2024 16:04:58 INFO 140464643696448] Epoch[11] Time cost=50.342
# [10/06/2024 16:04:58 INFO 140464643696448] Epoch[11] Validation-accuracy=0.834821
# [10/06/2024 16:05:02 INFO 140464643696448] Epoch[12] Batch [20]#011Speed: 188.751 samples/sec#011accuracy=0.994048
# [10/06/2024 16:05:05 INFO 140464643696448] Epoch[12] Batch [40]#011Speed: 191.309 samples/sec#011accuracy=0.996189
# [10/06/2024 16:05:09 INFO 140464643696448] Epoch[12] Batch [60]#011Speed: 193.136 samples/sec#011accuracy=0.995389
# [10/06/2024 16:05:12 INFO 140464643696448] Epoch[12] Batch [80]#011Speed: 193.969 samples/sec#011accuracy=0.996528
# [10/06/2024 16:05:15 INFO 140464643696448] Epoch[12] Batch [100]#011Speed: 194.563 samples/sec#011accuracy=0.996906
# [10/06/2024 16:05:18 INFO 140464643696448] Epoch[12] Batch [120]#011Speed: 195.250 samples/sec#011accuracy=0.997417
# [10/06/2024 16:05:22 INFO 140464643696448] Epoch[12] Batch [140]#011Speed: 195.751 samples/sec#011accuracy=0.997784
# [10/06/2024 16:05:25 INFO 140464643696448] Epoch[12] Batch [160]#011Speed: 195.900 samples/sec#011accuracy=0.998059
# [10/06/2024 16:05:28 INFO 140464643696448] Epoch[12] Batch [180]#011Speed: 196.290 samples/sec#011accuracy=0.998273
# [10/06/2024 16:05:31 INFO 140464643696448] Epoch[12] Batch [200]#011Speed: 196.335 samples/sec#011accuracy=0.998290
# [10/06/2024 16:05:35 INFO 140464643696448] Epoch[12] Batch [220]#011Speed: 196.406 samples/sec#011accuracy=0.998445
# [10/06/2024 16:05:38 INFO 140464643696448] Epoch[12] Batch [240]#011Speed: 196.664 samples/sec#011accuracy=0.998574
# [10/06/2024 16:05:41 INFO 140464643696448] Epoch[12] Batch [260]#011Speed: 196.502 samples/sec#011accuracy=0.998563
# [10/06/2024 16:05:44 INFO 140464643696448] Epoch[12] Batch [280]#011Speed: 196.742 samples/sec#011accuracy=0.998665
# [10/06/2024 16:05:47 INFO 140464643696448] Epoch[12] Batch [300]#011Speed: 196.898 samples/sec#011accuracy=0.998754
# [10/06/2024 16:05:49 INFO 140464643696448] Epoch[12] Train-accuracy=0.998698
# [10/06/2024 16:05:49 INFO 140464643696448] Epoch[12] Time cost=50.520
# [10/06/2024 16:05:50 INFO 140464643696448] Epoch[12] Validation-accuracy=0.869792
# [10/06/2024 16:05:50 INFO 140464643696448] Storing the best model with validation accuracy: 0.869792
# [10/06/2024 16:05:50 INFO 140464643696448] Saved checkpoint to "/opt/ml/model/image-classification-0013.params"
# [10/06/2024 16:05:54 INFO 140464643696448] Epoch[13] Batch [20]#011Speed: 191.533 samples/sec#011accuracy=0.998512
# [10/06/2024 16:05:57 INFO 140464643696448] Epoch[13] Batch [40]#011Speed: 194.193 samples/sec#011accuracy=0.996189
# [10/06/2024 16:06:00 INFO 140464643696448] Epoch[13] Batch [60]#011Speed: 195.339 samples/sec#011accuracy=0.996926
# [10/06/2024 16:06:04 INFO 140464643696448] Epoch[13] Batch [80]#011Speed: 194.086 samples/sec#011accuracy=0.997685
# [10/06/2024 16:06:07 INFO 140464643696448] Epoch[13] Batch [100]#011Speed: 194.795 samples/sec#011accuracy=0.998144
# [10/06/2024 16:06:10 INFO 140464643696448] Epoch[13] Batch [120]#011Speed: 195.178 samples/sec#011accuracy=0.998450
# [10/06/2024 16:06:13 INFO 140464643696448] Epoch[13] Batch [140]#011Speed: 195.363 samples/sec#011accuracy=0.998670
# [10/06/2024 16:06:17 INFO 140464643696448] Epoch[13] Batch [160]#011Speed: 195.231 samples/sec#011accuracy=0.998835
# [10/06/2024 16:06:20 INFO 140464643696448] Epoch[13] Batch [180]#011Speed: 195.530 samples/sec#011accuracy=0.998964
# [10/06/2024 16:06:23 INFO 140464643696448] Epoch[13] Batch [200]#011Speed: 195.751 samples/sec#011accuracy=0.999067
# [10/06/2024 16:06:26 INFO 140464643696448] Epoch[13] Batch [220]#011Speed: 195.849 samples/sec#011accuracy=0.999152
# [10/06/2024 16:06:30 INFO 140464643696448] Epoch[13] Batch [240]#011Speed: 196.098 samples/sec#011accuracy=0.999222
# [10/06/2024 16:06:33 INFO 140464643696448] Epoch[13] Batch [260]#011Speed: 196.242 samples/sec#011accuracy=0.999282
# [10/06/2024 16:06:36 INFO 140464643696448] Epoch[13] Batch [280]#011Speed: 196.260 samples/sec#011accuracy=0.999333
# [10/06/2024 16:06:39 INFO 140464643696448] Epoch[13] Batch [300]#011Speed: 196.368 samples/sec#011accuracy=0.999273
# [10/06/2024 16:06:41 INFO 140464643696448] Epoch[13] Train-accuracy=0.999299
# [10/06/2024 16:06:41 INFO 140464643696448] Epoch[13] Time cost=50.646
# [10/06/2024 16:06:41 INFO 140464643696448] Epoch[13] Validation-accuracy=0.838542
# [10/06/2024 16:06:45 INFO 140464643696448] Epoch[14] Batch [20]#011Speed: 192.434 samples/sec#011accuracy=1.000000
# [10/06/2024 16:06:48 INFO 140464643696448] Epoch[14] Batch [40]#011Speed: 193.998 samples/sec#011accuracy=1.000000
# [10/06/2024 16:06:52 INFO 140464643696448] Epoch[14] Batch [60]#011Speed: 195.123 samples/sec#011accuracy=1.000000
# [10/06/2024 16:06:55 INFO 140464643696448] Epoch[14] Batch [80]#011Speed: 195.974 samples/sec#011accuracy=1.000000
# [10/06/2024 16:06:58 INFO 140464643696448] Epoch[14] Batch [100]#011Speed: 196.629 samples/sec#011accuracy=1.000000
# [10/06/2024 16:07:01 INFO 140464643696448] Epoch[14] Batch [120]#011Speed: 196.629 samples/sec#011accuracy=1.000000
# [10/06/2024 16:07:05 INFO 140464643696448] Epoch[14] Batch [140]#011Speed: 196.224 samples/sec#011accuracy=0.999335
# [10/06/2024 16:07:08 INFO 140464643696448] Epoch[14] Batch [160]#011Speed: 196.328 samples/sec#011accuracy=0.999418
# [10/06/2024 16:07:11 INFO 140464643696448] Epoch[14] Batch [180]#011Speed: 196.518 samples/sec#011accuracy=0.999309
# [10/06/2024 16:07:14 INFO 140464643696448] Epoch[14] Batch [200]#011Speed: 196.628 samples/sec#011accuracy=0.999378
# [10/06/2024 16:07:18 INFO 140464643696448] Epoch[14] Batch [220]#011Speed: 196.830 samples/sec#011accuracy=0.999293
# [10/06/2024 16:07:21 INFO 140464643696448] Epoch[14] Batch [240]#011Speed: 197.081 samples/sec#011accuracy=0.999092
# [10/06/2024 16:07:24 INFO 140464643696448] Epoch[14] Batch [260]#011Speed: 197.090 samples/sec#011accuracy=0.998922
# [10/06/2024 16:07:27 INFO 140464643696448] Epoch[14] Batch [280]#011Speed: 197.097 samples/sec#011accuracy=0.998888
# [10/06/2024 16:07:31 INFO 140464643696448] Epoch[14] Batch [300]#011Speed: 197.154 samples/sec#011accuracy=0.998858
# [10/06/2024 16:07:32 INFO 140464643696448] Epoch[14] Train-accuracy=0.998898
# [10/06/2024 16:07:32 INFO 140464643696448] Epoch[14] Time cost=50.483
# [10/06/2024 16:07:33 INFO 140464643696448] Epoch[14] Validation-accuracy=0.869792
# [10/06/2024 16:07:37 INFO 140464643696448] Epoch[15] Batch [20]#011Speed: 164.143 samples/sec#011accuracy=0.998512
# [10/06/2024 16:07:40 INFO 140464643696448] Epoch[15] Batch [40]#011Speed: 179.781 samples/sec#011accuracy=0.999238
# [10/06/2024 16:07:44 INFO 140464643696448] Epoch[15] Batch [60]#011Speed: 185.179 samples/sec#011accuracy=0.998975
# [10/06/2024 16:07:47 INFO 140464643696448] Epoch[15] Batch [80]#011Speed: 187.961 samples/sec#011accuracy=0.998843
# [10/06/2024 16:07:50 INFO 140464643696448] Epoch[15] Batch [100]#011Speed: 189.890 samples/sec#011accuracy=0.998762
# [10/06/2024 16:07:53 INFO 140464643696448] Epoch[15] Batch [120]#011Speed: 191.269 samples/sec#011accuracy=0.998450
# [10/06/2024 16:07:57 INFO 140464643696448] Epoch[15] Batch [140]#011Speed: 192.149 samples/sec#011accuracy=0.998449
# [10/06/2024 16:08:00 INFO 140464643696448] Epoch[15] Batch [160]#011Speed: 192.618 samples/sec#011accuracy=0.998641
# [10/06/2024 16:08:03 INFO 140464643696448] Epoch[15] Batch [180]#011Speed: 192.439 samples/sec#011accuracy=0.998619
# [10/06/2024 16:08:06 INFO 140464643696448] Epoch[15] Batch [200]#011Speed: 193.084 samples/sec#011accuracy=0.998756
# [10/06/2024 16:08:10 INFO 140464643696448] Epoch[15] Batch [220]#011Speed: 193.535 samples/sec#011accuracy=0.998020
# [10/06/2024 16:08:13 INFO 140464643696448] Epoch[15] Batch [240]#011Speed: 193.915 samples/sec#011accuracy=0.996888
# [10/06/2024 16:08:16 INFO 140464643696448] Epoch[15] Batch [260]#011Speed: 194.332 samples/sec#011accuracy=0.994971
# [10/06/2024 16:08:19 INFO 140464643696448] Epoch[15] Batch [280]#011Speed: 194.570 samples/sec#011accuracy=0.993883
# [10/06/2024 16:08:23 INFO 140464643696448] Epoch[15] Batch [300]#011Speed: 194.678 samples/sec#011accuracy=0.993875
# [10/06/2024 16:08:24 INFO 140464643696448] Epoch[15] Train-accuracy=0.994091
# [10/06/2024 16:08:24 INFO 140464643696448] Epoch[15] Time cost=51.098
# [10/06/2024 16:08:25 INFO 140464643696448] Epoch[15] Validation-accuracy=0.852679
# [10/06/2024 16:08:29 INFO 140464643696448] Epoch[16] Batch [20]#011Speed: 192.159 samples/sec#011accuracy=1.000000
# [10/06/2024 16:08:32 INFO 140464643696448] Epoch[16] Batch [40]#011Speed: 194.234 samples/sec#011accuracy=0.999238
# [10/06/2024 16:08:35 INFO 140464643696448] Epoch[16] Batch [60]#011Speed: 195.387 samples/sec#011accuracy=0.998975
# [10/06/2024 16:08:38 INFO 140464643696448] Epoch[16] Batch [80]#011Speed: 196.026 samples/sec#011accuracy=0.999228
# [10/06/2024 16:08:42 INFO 140464643696448] Epoch[16] Batch [100]#011Speed: 196.561 samples/sec#011accuracy=0.998453
# [10/06/2024 16:08:45 INFO 140464643696448] Epoch[16] Batch [120]#011Speed: 196.876 samples/sec#011accuracy=0.997934
# [10/06/2024 16:08:48 INFO 140464643696448] Epoch[16] Batch [140]#011Speed: 196.927 samples/sec#011accuracy=0.997562
# [10/06/2024 16:08:51 INFO 140464643696448] Epoch[16] Batch [160]#011Speed: 196.920 samples/sec#011accuracy=0.997865
# [10/06/2024 16:08:55 INFO 140464643696448] Epoch[16] Batch [180]#011Speed: 197.053 samples/sec#011accuracy=0.997238
# [10/06/2024 16:08:58 INFO 140464643696448] Epoch[16] Batch [200]#011Speed: 197.169 samples/sec#011accuracy=0.996891
# [10/06/2024 16:09:01 INFO 140464643696448] Epoch[16] Batch [220]#011Speed: 197.007 samples/sec#011accuracy=0.996748
# [10/06/2024 16:09:04 INFO 140464643696448] Epoch[16] Batch [240]#011Speed: 196.689 samples/sec#011accuracy=0.996629
# [10/06/2024 16:09:08 INFO 140464643696448] Epoch[16] Batch [260]#011Speed: 196.852 samples/sec#011accuracy=0.996528
# [10/06/2024 16:09:11 INFO 140464643696448] Epoch[16] Batch [280]#011Speed: 196.927 samples/sec#011accuracy=0.995996
# [10/06/2024 16:09:14 INFO 140464643696448] Epoch[16] Batch [300]#011Speed: 196.961 samples/sec#011accuracy=0.995640
# [10/06/2024 16:09:16 INFO 140464643696448] Epoch[16] Train-accuracy=0.995693
# [10/06/2024 16:09:16 INFO 140464643696448] Epoch[16] Time cost=50.507
# [10/06/2024 16:09:16 INFO 140464643696448] Epoch[16] Validation-accuracy=0.812500
# [10/06/2024 16:09:20 INFO 140464643696448] Epoch[17] Batch [20]#011Speed: 192.813 samples/sec#011accuracy=1.000000
# [10/06/2024 16:09:23 INFO 140464643696448] Epoch[17] Batch [40]#011Speed: 195.614 samples/sec#011accuracy=0.997713
# [10/06/2024 16:09:27 INFO 140464643696448] Epoch[17] Batch [60]#011Speed: 196.925 samples/sec#011accuracy=0.996414
# [10/06/2024 16:09:30 INFO 140464643696448] Epoch[17] Batch [80]#011Speed: 197.268 samples/sec#011accuracy=0.996142
# [10/06/2024 16:09:33 INFO 140464643696448] Epoch[17] Batch [100]#011Speed: 197.210 samples/sec#011accuracy=0.996597
# [10/06/2024 16:09:36 INFO 140464643696448] Epoch[17] Batch [120]#011Speed: 197.325 samples/sec#011accuracy=0.997159
# [10/06/2024 16:09:39 INFO 140464643696448] Epoch[17] Batch [140]#011Speed: 197.457 samples/sec#011accuracy=0.997562
# [10/06/2024 16:09:43 INFO 140464643696448] Epoch[17] Batch [160]#011Speed: 197.431 samples/sec#011accuracy=0.997671
# [10/06/2024 16:09:46 INFO 140464643696448] Epoch[17] Batch [180]#011Speed: 197.468 samples/sec#011accuracy=0.997410
# [10/06/2024 16:09:49 INFO 140464643696448] Epoch[17] Batch [200]#011Speed: 197.428 samples/sec#011accuracy=0.997668
# [10/06/2024 16:09:52 INFO 140464643696448] Epoch[17] Batch [220]#011Speed: 197.486 samples/sec#011accuracy=0.997879
# [10/06/2024 16:09:56 INFO 140464643696448] Epoch[17] Batch [240]#011Speed: 197.589 samples/sec#011accuracy=0.997925
# [10/06/2024 16:09:59 INFO 140464643696448] Epoch[17] Batch [260]#011Speed: 197.628 samples/sec#011accuracy=0.998084
# [10/06/2024 16:10:02 INFO 140464643696448] Epoch[17] Batch [280]#011Speed: 197.478 samples/sec#011accuracy=0.998221
# [10/06/2024 16:10:05 INFO 140464643696448] Epoch[17] Batch [300]#011Speed: 197.193 samples/sec#011accuracy=0.998339
# [10/06/2024 16:10:07 INFO 140464643696448] Epoch[17] Train-accuracy=0.998397
# [10/06/2024 16:10:07 INFO 140464643696448] Epoch[17] Time cost=50.460
# [10/06/2024 16:10:08 INFO 140464643696448] Epoch[17] Validation-accuracy=0.859375
# [10/06/2024 16:10:12 INFO 140464643696448] Epoch[18] Batch [20]#011Speed: 192.505 samples/sec#011accuracy=1.000000
# [10/06/2024 16:10:15 INFO 140464643696448] Epoch[18] Batch [40]#011Speed: 194.861 samples/sec#011accuracy=1.000000
# [10/06/2024 16:10:18 INFO 140464643696448] Epoch[18] Batch [60]#011Speed: 196.229 samples/sec#011accuracy=0.997951
# [10/06/2024 16:10:21 INFO 140464643696448] Epoch[18] Batch [80]#011Speed: 196.629 samples/sec#011accuracy=0.996914
# [10/06/2024 16:10:24 INFO 140464643696448] Epoch[18] Batch [100]#011Speed: 196.796 samples/sec#011accuracy=0.996906
# [10/06/2024 16:10:28 INFO 140464643696448] Epoch[18] Batch [120]#011Speed: 196.997 samples/sec#011accuracy=0.997417
# [10/06/2024 16:10:31 INFO 140464643696448] Epoch[18] Batch [140]#011Speed: 197.123 samples/sec#011accuracy=0.997784
# [10/06/2024 16:10:34 INFO 140464643696448] Epoch[18] Batch [160]#011Speed: 197.252 samples/sec#011accuracy=0.998059
# [10/06/2024 16:10:37 INFO 140464643696448] Epoch[18] Batch [180]#011Speed: 197.266 samples/sec#011accuracy=0.998101
# [10/06/2024 16:10:41 INFO 140464643696448] Epoch[18] Batch [200]#011Speed: 197.309 samples/sec#011accuracy=0.996580
# [10/06/2024 16:10:44 INFO 140464643696448] Epoch[18] Batch [220]#011Speed: 197.239 samples/sec#011accuracy=0.996182
# [10/06/2024 16:10:47 INFO 140464643696448] Epoch[18] Batch [240]#011Speed: 197.258 samples/sec#011accuracy=0.995851
# [10/06/2024 16:10:50 INFO 140464643696448] Epoch[18] Batch [260]#011Speed: 197.339 samples/sec#011accuracy=0.995330
# [10/06/2024 16:10:54 INFO 140464643696448] Epoch[18] Batch [280]#011Speed: 197.457 samples/sec#011accuracy=0.994996
# [10/06/2024 16:10:57 INFO 140464643696448] Epoch[18] Batch [300]#011Speed: 197.437 samples/sec#011accuracy=0.995328
# [10/06/2024 16:10:59 INFO 140464643696448] Epoch[18] Train-accuracy=0.995393
# [10/06/2024 16:10:59 INFO 140464643696448] Epoch[18] Time cost=50.407
# [10/06/2024 16:10:59 INFO 140464643696448] Epoch[18] Validation-accuracy=0.869792
# [10/06/2024 16:11:03 INFO 140464643696448] Epoch[19] Batch [20]#011Speed: 190.525 samples/sec#011accuracy=1.000000
# [10/06/2024 16:11:06 INFO 140464643696448] Epoch[19] Batch [40]#011Speed: 192.492 samples/sec#011accuracy=0.998476
# [10/06/2024 16:11:09 INFO 140464643696448] Epoch[19] Batch [60]#011Speed: 194.225 samples/sec#011accuracy=0.997439
# [10/06/2024 16:11:13 INFO 140464643696448] Epoch[19] Batch [80]#011Speed: 195.290 samples/sec#011accuracy=0.998071
# [10/06/2024 16:11:16 INFO 140464643696448] Epoch[19] Batch [100]#011Speed: 195.773 samples/sec#011accuracy=0.998453
# [10/06/2024 16:11:19 INFO 140464643696448] Epoch[19] Batch [120]#011Speed: 196.112 samples/sec#011accuracy=0.998709
# [10/06/2024 16:11:22 INFO 140464643696448] Epoch[19] Batch [140]#011Speed: 196.272 samples/sec#011accuracy=0.998892
# [10/06/2024 16:11:26 INFO 140464643696448] Epoch[19] Batch [160]#011Speed: 196.417 samples/sec#011accuracy=0.999030
# [10/06/2024 16:11:29 INFO 140464643696448] Epoch[19] Batch [180]#011Speed: 196.504 samples/sec#011accuracy=0.999137
# [10/06/2024 16:11:32 INFO 140464643696448] Epoch[19] Batch [200]#011Speed: 196.683 samples/sec#011accuracy=0.999223
# [10/06/2024 16:11:35 INFO 140464643696448] Epoch[19] Batch [220]#011Speed: 196.708 samples/sec#011accuracy=0.999293
# [10/06/2024 16:11:39 INFO 140464643696448] Epoch[19] Batch [240]#011Speed: 196.712 samples/sec#011accuracy=0.999352
# [10/06/2024 16:11:42 INFO 140464643696448] Epoch[19] Batch [260]#011Speed: 196.702 samples/sec#011accuracy=0.999401
# [10/06/2024 16:11:45 INFO 140464643696448] Epoch[19] Batch [280]#011Speed: 196.756 samples/sec#011accuracy=0.999444
# [10/06/2024 16:11:48 INFO 140464643696448] Epoch[19] Batch [300]#011Speed: 196.760 samples/sec#011accuracy=0.999481
# [10/06/2024 16:11:50 INFO 140464643696448] Epoch[19] Train-accuracy=0.999499
# [10/06/2024 16:11:50 INFO 140464643696448] Epoch[19] Time cost=50.589
# [10/06/2024 16:11:51 INFO 140464643696448] Epoch[19] Validation-accuracy=0.825893
# [10/06/2024 16:11:54 INFO 140464643696448] Epoch[20] Batch [20]#011Speed: 191.926 samples/sec#011accuracy=1.000000
# [10/06/2024 16:11:58 INFO 140464643696448] Epoch[20] Batch [40]#011Speed: 195.428 samples/sec#011accuracy=1.000000
# [10/06/2024 16:12:01 INFO 140464643696448] Epoch[20] Batch [60]#011Speed: 196.089 samples/sec#011accuracy=1.000000
# [10/06/2024 16:12:04 INFO 140464643696448] Epoch[20] Batch [80]#011Speed: 195.164 samples/sec#011accuracy=1.000000
# [10/06/2024 16:12:07 INFO 140464643696448] Epoch[20] Batch [100]#011Speed: 195.659 samples/sec#011accuracy=1.000000
# [10/06/2024 16:12:11 INFO 140464643696448] Epoch[20] Batch [120]#011Speed: 196.185 samples/sec#011accuracy=1.000000
# [10/06/2024 16:12:14 INFO 140464643696448] Epoch[20] Batch [140]#011Speed: 196.106 samples/sec#011accuracy=1.000000
# [10/06/2024 16:12:17 INFO 140464643696448] Epoch[20] Batch [160]#011Speed: 196.233 samples/sec#011accuracy=1.000000
# [10/06/2024 16:12:20 INFO 140464643696448] Epoch[20] Batch [180]#011Speed: 196.559 samples/sec#011accuracy=1.000000
# [10/06/2024 16:12:24 INFO 140464643696448] Epoch[20] Batch [200]#011Speed: 196.918 samples/sec#011accuracy=1.000000
# [10/06/2024 16:12:27 INFO 140464643696448] Epoch[20] Batch [220]#011Speed: 196.965 samples/sec#011accuracy=1.000000
# ...
# [10/06/2024 16:13:33 INFO 140464643696448] Epoch[21] Validation-accuracy=0.843750
# [10/06/2024 16:13:37 INFO 140464643696448] Epoch[22] Batch [20]#011Speed: 194.056 samples/sec#011accuracy=1.000000
# [10/06/2024 16:13:40 INFO 140464643696448] Epoch[22] Batch [40]#011Speed: 196.061 samples/sec#011accuracy=1.000000
# [10/06/2024 16:13:44 INFO 140464643696448] Epoch[22] Batch [60]#011Speed: 196.394 samples/sec#011accuracy=1.000000
# [10/06/2024 16:13:47 INFO 140464643696448] Epoch[22] Batch [80]#011Speed: 196.725 samples/sec#011accuracy=1.000000
# [10/06/2024 16:13:50 INFO 140464643696448] Epoch[22] Batch [100]#011Speed: 197.240 samples/sec#011accuracy=0.999691
# [10/06/2024 16:13:53 INFO 140464643696448] Epoch[22] Batch [120]#011Speed: 197.161 samples/sec#011accuracy=0.999225
# [10/06/2024 16:13:57 INFO 140464643696448] Epoch[22] Batch [140]#011Speed: 197.352 samples/sec#011accuracy=0.999113
# [10/06/2024 16:14:00 INFO 140464643696448] Epoch[22] Batch [160]#011Speed: 197.292 samples/sec#011accuracy=0.999224
# [10/06/2024 16:14:03 INFO 140464643696448] Epoch[22] Batch [180]#011Speed: 196.635 samples/sec#011accuracy=0.999309
# [10/06/2024 16:14:06 INFO 140464643696448] Epoch[22] Batch [200]#011Speed: 196.872 samples/sec#011accuracy=0.999378
# [10/06/2024 16:14:10 INFO 140464643696448] Epoch[22] Batch [220]#011Speed: 196.879 samples/sec#011accuracy=0.999434
# [10/06/2024 16:14:13 INFO 140464643696448] Epoch[22] Batch [240]#011Speed: 197.076 samples/sec#011accuracy=0.999481
# [10/06/2024 16:14:16 INFO 140464643696448] Epoch[22] Batch [260]#011Speed: 197.250 samples/sec#011accuracy=0.999521
# [10/06/2024 16:14:19 INFO 140464643696448] Epoch[22] Batch [280]#011Speed: 197.298 samples/sec#011accuracy=0.999555
# [10/06/2024 16:14:22 INFO 140464643696448] Epoch[22] Batch [300]#011Speed: 197.405 samples/sec#011accuracy=0.999585
# [10/06/2024 16:14:24 INFO 140464643696448] Epoch[22] Train-accuracy=0.999599
# [10/06/2024 16:14:24 INFO 140464643696448] Epoch[22] Time cost=50.406
# [10/06/2024 16:14:25 INFO 140464643696448] Epoch[22] Validation-accuracy=0.817708
# [10/06/2024 16:14:29 INFO 140464643696448] Epoch[23] Batch [20]#011Speed: 193.674 samples/sec#011accuracy=1.000000
# [10/06/2024 16:14:32 INFO 140464643696448] Epoch[23] Batch [40]#011Speed: 195.091 samples/sec#011accuracy=1.000000
# [10/06/2024 16:14:35 INFO 140464643696448] Epoch[23] Batch [60]#011Speed: 196.374 samples/sec#011accuracy=1.000000
# [10/06/2024 16:14:38 INFO 140464643696448] Epoch[23] Batch [80]#011Speed: 196.678 samples/sec#011accuracy=1.000000
# [10/06/2024 16:14:41 INFO 140464643696448] Epoch[23] Batch [100]#011Speed: 197.165 samples/sec#011accuracy=1.000000
# [10/06/2024 16:14:45 INFO 140464643696448] Epoch[23] Batch [120]#011Speed: 196.909 samples/sec#011accuracy=1.000000
# [10/06/2024 16:14:48 INFO 140464643696448] Epoch[23] Batch [140]#011Speed: 196.744 samples/sec#011accuracy=0.999778
# [10/06/2024 16:14:51 INFO 140464643696448] Epoch[23] Batch [160]#011Speed: 196.683 samples/sec#011accuracy=0.999612
# [10/06/2024 16:14:54 INFO 140464643696448] Epoch[23] Batch [180]#011Speed: 196.773 samples/sec#011accuracy=0.999309
# [10/06/2024 16:14:58 INFO 140464643696448] Epoch[23] Batch [200]#011Speed: 196.886 samples/sec#011accuracy=0.998134
# [10/06/2024 16:15:01 INFO 140464643696448] Epoch[23] Batch [220]#011Speed: 196.972 samples/sec#011accuracy=0.996889
# [10/06/2024 16:15:04 INFO 140464643696448] Epoch[23] Batch [240]#011Speed: 196.477 samples/sec#011accuracy=0.995721
# [10/06/2024 16:15:08 INFO 140464643696448] Epoch[23] Batch [260]#011Speed: 196.523 samples/sec#011accuracy=0.995091
# [10/06/2024 16:15:11 INFO 140464643696448] Epoch[23] Batch [280]#011Speed: 196.567 samples/sec#011accuracy=0.995107
# [10/06/2024 16:15:14 INFO 140464643696448] Epoch[23] Batch [300]#011Speed: 196.644 samples/sec#011accuracy=0.995120
# [10/06/2024 16:15:16 INFO 140464643696448] Epoch[23] Train-accuracy=0.995292
# [10/06/2024 16:15:16 INFO 140464643696448] Epoch[23] Time cost=50.595
# [10/06/2024 16:15:16 INFO 140464643696448] Epoch[23] Validation-accuracy=0.799107
# [10/06/2024 16:15:20 INFO 140464643696448] Epoch[24] Batch [20]#011Speed: 193.272 samples/sec#011accuracy=0.998512
# [10/06/2024 16:15:23 INFO 140464643696448] Epoch[24] Batch [40]#011Speed: 196.438 samples/sec#011accuracy=0.999238
# [10/06/2024 16:15:27 INFO 140464643696448] Epoch[24] Batch [60]#011Speed: 196.511 samples/sec#011accuracy=0.999488
# [10/06/2024 16:15:30 INFO 140464643696448] Epoch[24] Batch [80]#011Speed: 196.988 samples/sec#011accuracy=0.999614
# [10/06/2024 16:15:33 INFO 140464643696448] Epoch[24] Batch [100]#011Speed: 197.400 samples/sec#011accuracy=0.999691
# [10/06/2024 16:15:36 INFO 140464643696448] Epoch[24] Batch [120]#011Speed: 197.542 samples/sec#011accuracy=0.999742
# [10/06/2024 16:15:39 INFO 140464643696448] Epoch[24] Batch [140]#011Speed: 197.533 samples/sec#011accuracy=0.999778
# [10/06/2024 16:15:43 INFO 140464643696448] Epoch[24] Batch [160]#011Speed: 197.497 samples/sec#011accuracy=0.999806
# [10/06/2024 16:15:46 INFO 140464643696448] Epoch[24] Batch [180]#011Speed: 197.542 samples/sec#011accuracy=0.999827
# [10/06/2024 16:15:49 INFO 140464643696448] Epoch[24] Batch [200]#011Speed: 197.605 samples/sec#011accuracy=0.999845
# [10/06/2024 16:15:52 INFO 140464643696448] Epoch[24] Batch [220]#011Speed: 197.594 samples/sec#011accuracy=0.999859
# [10/06/2024 16:15:56 INFO 140464643696448] Epoch[24] Batch [240]#011Speed: 197.695 samples/sec#011accuracy=0.999870
# [10/06/2024 16:15:59 INFO 140464643696448] Epoch[24] Batch [260]#011Speed: 197.843 samples/sec#011accuracy=0.999880
# [10/06/2024 16:16:02 INFO 140464643696448] Epoch[24] Batch [280]#011Speed: 197.693 samples/sec#011accuracy=0.999555
# [10/06/2024 16:16:05 INFO 140464643696448] Epoch[24] Batch [300]#011Speed: 197.385 samples/sec#011accuracy=0.999585
# [10/06/2024 16:16:07 INFO 140464643696448] Epoch[24] Train-accuracy=0.999499
# [10/06/2024 16:16:07 INFO 140464643696448] Epoch[24] Time cost=50.412
# [10/06/2024 16:16:08 INFO 140464643696448] Epoch[24] Validation-accuracy=0.796875
# [10/06/2024 16:16:11 INFO 140464643696448] Epoch[25] Batch [20]#011Speed: 194.554 samples/sec#011accuracy=0.998512
# [10/06/2024 16:16:15 INFO 140464643696448] Epoch[25] Batch [40]#011Speed: 196.960 samples/sec#011accuracy=0.998476
# [10/06/2024 16:16:18 INFO 140464643696448] Epoch[25] Batch [60]#011Speed: 197.071 samples/sec#011accuracy=0.997951
# [10/06/2024 16:16:21 INFO 140464643696448] Epoch[25] Batch [80]#011Speed: 197.677 samples/sec#011accuracy=0.998071
# [10/06/2024 16:16:24 INFO 140464643696448] Epoch[25] Batch [100]#011Speed: 197.802 samples/sec#011accuracy=0.998144
# [10/06/2024 16:16:27 INFO 140464643696448] Epoch[25] Batch [120]#011Speed: 197.870 samples/sec#011accuracy=0.998192
# [10/06/2024 16:16:31 INFO 140464643696448] Epoch[25] Batch [140]#011Speed: 197.975 samples/sec#011accuracy=0.998449
# [10/06/2024 16:16:34 INFO 140464643696448] Epoch[25] Batch [160]#011Speed: 197.817 samples/sec#011accuracy=0.998641
# [10/06/2024 16:16:37 INFO 140464643696448] Epoch[25] Batch [180]#011Speed: 197.871 samples/sec#011accuracy=0.998619
# [10/06/2024 16:16:40 INFO 140464643696448] Epoch[25] Batch [200]#011Speed: 197.779 samples/sec#011accuracy=0.998756
# [10/06/2024 16:16:44 INFO 140464643696448] Epoch[25] Batch [220]#011Speed: 197.776 samples/sec#011accuracy=0.998869
# [10/06/2024 16:16:47 INFO 140464643696448] Epoch[25] Batch [240]#011Speed: 197.734 samples/sec#011accuracy=0.998703
# [10/06/2024 16:16:50 INFO 140464643696448] Epoch[25] Batch [260]#011Speed: 197.691 samples/sec#011accuracy=0.998204
# [10/06/2024 16:16:53 INFO 140464643696448] Epoch[25] Batch [280]#011Speed: 197.612 samples/sec#011accuracy=0.997665
# [10/06/2024 16:16:57 INFO 140464643696448] Epoch[25] Batch [300]#011Speed: 197.542 samples/sec#011accuracy=0.997301
# [10/06/2024 16:16:58 INFO 140464643696448] Epoch[25] Train-accuracy=0.997095
# [10/06/2024 16:16:58 INFO 140464643696448] Epoch[25] Time cost=50.385
# [10/06/2024 16:16:59 INFO 140464643696448] Epoch[25] Validation-accuracy=0.828125
# [10/06/2024 16:17:03 INFO 140464643696448] Epoch[26] Batch [20]#011Speed: 186.731 samples/sec#011accuracy=0.986607
# [10/06/2024 16:17:06 INFO 140464643696448] Epoch[26] Batch [40]#011Speed: 192.178 samples/sec#011accuracy=0.988567
# [10/06/2024 16:17:09 INFO 140464643696448] Epoch[26] Batch [60]#011Speed: 194.017 samples/sec#011accuracy=0.987705
# [10/06/2024 16:17:13 INFO 140464643696448] Epoch[26] Batch [80]#011Speed: 194.893 samples/sec#011accuracy=0.986497
# [10/06/2024 16:17:16 INFO 140464643696448] Epoch[26] Batch [100]#011Speed: 195.316 samples/sec#011accuracy=0.984839
# [10/06/2024 16:17:19 INFO 140464643696448] Epoch[26] Batch [120]#011Speed: 196.075 samples/sec#011accuracy=0.986312
# [10/06/2024 16:17:22 INFO 140464643696448] Epoch[26] Batch [140]#011Speed: 196.431 samples/sec#011accuracy=0.988032
# [10/06/2024 16:17:25 INFO 140464643696448] Epoch[26] Batch [160]#011Speed: 196.547 samples/sec#011accuracy=0.989519
# [10/06/2024 16:17:29 INFO 140464643696448] Epoch[26] Batch [180]#011Speed: 196.775 samples/sec#011accuracy=0.990504
# [10/06/2024 16:17:32 INFO 140464643696448] Epoch[26] Batch [200]#011Speed: 196.914 samples/sec#011accuracy=0.991449
# [10/06/2024 16:17:35 INFO 140464643696448] Epoch[26] Batch [220]#011Speed: 197.023 samples/sec#011accuracy=0.992081
# [10/06/2024 16:17:38 INFO 140464643696448] Epoch[26] Batch [240]#011Speed: 197.166 samples/sec#011accuracy=0.992479
# [10/06/2024 16:17:42 INFO 140464643696448] Epoch[26] Batch [260]#011Speed: 197.333 samples/sec#011accuracy=0.992936
# [10/06/2024 16:17:45 INFO 140464643696448] Epoch[26] Batch [280]#011Speed: 197.300 samples/sec#011accuracy=0.993327
# [10/06/2024 16:17:48 INFO 140464643696448] Epoch[26] Batch [300]#011Speed: 197.419 samples/sec#011accuracy=0.993771
# [10/06/2024 16:17:50 INFO 140464643696448] Epoch[26] Train-accuracy=0.993990
# [10/06/2024 16:17:50 INFO 140464643696448] Epoch[26] Time cost=50.409
# [10/06/2024 16:17:50 INFO 140464643696448] Epoch[26] Validation-accuracy=0.843750
# [10/06/2024 16:17:54 INFO 140464643696448] Epoch[27] Batch [20]#011Speed: 194.625 samples/sec#011accuracy=1.000000
# [10/06/2024 16:17:57 INFO 140464643696448] Epoch[27] Batch [40]#011Speed: 196.655 samples/sec#011accuracy=1.000000
# [10/06/2024 16:18:01 INFO 140464643696448] Epoch[27] Batch [60]#011Speed: 196.833 samples/sec#011accuracy=1.000000
# [10/06/2024 16:18:04 INFO 140464643696448] Epoch[27] Batch [80]#011Speed: 195.634 samples/sec#011accuracy=1.000000
# [10/06/2024 16:18:07 INFO 140464643696448] Epoch[27] Batch [100]#011Speed: 195.615 samples/sec#011accuracy=1.000000
# [10/06/2024 16:18:10 INFO 140464643696448] Epoch[27] Batch [120]#011Speed: 195.789 samples/sec#011accuracy=1.000000
# [10/06/2024 16:18:14 INFO 140464643696448] Epoch[27] Batch [140]#011Speed: 195.971 samples/sec#011accuracy=1.000000
# [10/06/2024 16:18:17 INFO 140464643696448] Epoch[27] Batch [160]#011Speed: 196.375 samples/sec#011accuracy=1.000000
# [10/06/2024 16:18:20 INFO 140464643696448] Epoch[27] Batch [180]#011Speed: 196.576 samples/sec#011accuracy=1.000000
# [10/06/2024 16:18:23 INFO 140464643696448] Epoch[27] Batch [200]#011Speed: 196.745 samples/sec#011accuracy=1.000000
# [10/06/2024 16:18:27 INFO 140464643696448] Epoch[27] Batch [220]#011Speed: 196.882 samples/sec#011accuracy=1.000000
# [10/06/2024 16:18:30 INFO 140464643696448] Epoch[27] Batch [240]#011Speed: 196.972 samples/sec#011accuracy=1.000000
# [10/06/2024 16:18:33 INFO 140464643696448] Epoch[27] Batch [260]#011Speed: 197.192 samples/sec#011accuracy=1.000000
# [10/06/2024 16:18:36 INFO 140464643696448] Epoch[27] Batch [280]#011Speed: 197.352 samples/sec#011accuracy=1.000000
# [10/06/2024 16:18:39 INFO 140464643696448] Epoch[27] Batch [300]#011Speed: 197.432 samples/sec#011accuracy=1.000000
# [10/06/2024 16:18:41 INFO 140464643696448] Epoch[27] Train-accuracy=1.000000
# [10/06/2024 16:18:41 INFO 140464643696448] Epoch[27] Time cost=50.381
# [10/06/2024 16:18:42 INFO 140464643696448] Epoch[27] Validation-accuracy=0.834821
# [10/06/2024 16:18:45 INFO 140464643696448] Epoch[28] Batch [20]#011Speed: 193.112 samples/sec#011accuracy=1.000000
# [10/06/2024 16:18:49 INFO 140464643696448] Epoch[28] Batch [40]#011Speed: 194.255 samples/sec#011accuracy=1.000000
# [10/06/2024 16:18:52 INFO 140464643696448] Epoch[28] Batch [60]#011Speed: 194.981 samples/sec#011accuracy=1.000000
# [10/06/2024 16:18:55 INFO 140464643696448] Epoch[28] Batch [80]#011Speed: 195.307 samples/sec#011accuracy=1.000000
# [10/06/2024 16:18:59 INFO 140464643696448] Epoch[28] Batch [100]#011Speed: 195.709 samples/sec#011accuracy=1.000000
# [10/06/2024 16:19:02 INFO 140464643696448] Epoch[28] Batch [120]#011Speed: 195.659 samples/sec#011accuracy=1.000000
# [10/06/2024 16:19:05 INFO 140464643696448] Epoch[28] Batch [140]#011Speed: 195.260 samples/sec#011accuracy=1.000000
# [10/06/2024 16:19:08 INFO 140464643696448] Epoch[28] Batch [160]#011Speed: 195.763 samples/sec#011accuracy=1.000000
# [10/06/2024 16:19:12 INFO 140464643696448] Epoch[28] Batch [180]#011Speed: 195.974 samples/sec#011accuracy=0.999827
# [10/06/2024 16:19:15 INFO 140464643696448] Epoch[28] Batch [200]#011Speed: 196.200 samples/sec#011accuracy=0.999845
# [10/06/2024 16:19:18 INFO 140464643696448] Epoch[28] Batch [220]#011Speed: 196.467 samples/sec#011accuracy=0.999859
# [10/06/2024 16:19:21 INFO 140464643696448] Epoch[28] Batch [240]#011Speed: 196.777 samples/sec#011accuracy=0.999870
# [10/06/2024 16:19:24 INFO 140464643696448] Epoch[28] Batch [260]#011Speed: 196.895 samples/sec#011accuracy=0.999880
# [10/06/2024 16:19:28 INFO 140464643696448] Epoch[28] Batch [280]#011Speed: 196.977 samples/sec#011accuracy=0.999889
# [10/06/2024 16:19:31 INFO 140464643696448] Epoch[28] Batch [300]#011Speed: 196.848 samples/sec#011accuracy=0.999896
# [10/06/2024 16:19:33 INFO 140464643696448] Epoch[28] Train-accuracy=0.999800
# [10/06/2024 16:19:33 INFO 140464643696448] Epoch[28] Time cost=50.552
# [10/06/2024 16:19:33 INFO 140464643696448] Epoch[28] Validation-accuracy=0.854167
# [10/06/2024 16:19:37 INFO 140464643696448] Epoch[29] Batch [20]#011Speed: 193.148 samples/sec#011accuracy=0.995536
# [10/06/2024 16:19:40 INFO 140464643696448] Epoch[29] Batch [40]#011Speed: 196.095 samples/sec#011accuracy=0.997713
# [10/06/2024 16:19:43 INFO 140464643696448] Epoch[29] Batch [60]#011Speed: 196.577 samples/sec#011accuracy=0.997439
# [10/06/2024 16:19:47 INFO 140464643696448] Epoch[29] Batch [80]#011Speed: 197.043 samples/sec#011accuracy=0.997299
# [10/06/2024 16:19:50 INFO 140464643696448] Epoch[29] Batch [100]#011Speed: 197.264 samples/sec#011accuracy=0.995668
# [10/06/2024 16:19:53 INFO 140464643696448] Epoch[29] Batch [120]#011Speed: 197.305 samples/sec#011accuracy=0.996126
# [10/06/2024 16:19:56 INFO 140464643696448] Epoch[29] Batch [140]#011Speed: 197.407 samples/sec#011accuracy=0.995789
# [10/06/2024 16:20:00 INFO 140464643696448] Epoch[29] Batch [160]#011Speed: 197.467 samples/sec#011accuracy=0.996118
# [10/06/2024 16:20:03 INFO 140464643696448] Epoch[29] Batch [180]#011Speed: 196.744 samples/sec#011accuracy=0.996374
# [10/06/2024 16:20:06 INFO 140464643696448] Epoch[29] Batch [200]#011Speed: 196.795 samples/sec#011accuracy=0.996735
# [10/06/2024 16:20:09 INFO 140464643696448] Epoch[29] Batch [220]#011Speed: 196.870 samples/sec#011accuracy=0.997031
# [10/06/2024 16:20:13 INFO 140464643696448] Epoch[29] Batch [240]#011Speed: 196.990 samples/sec#011accuracy=0.997147
# [10/06/2024 16:20:16 INFO 140464643696448] Epoch[29] Batch [260]#011Speed: 197.001 samples/sec#011accuracy=0.997007
# [10/06/2024 16:20:19 INFO 140464643696448] Epoch[29] Batch [280]#011Speed: 196.977 samples/sec#011accuracy=0.996552
# [10/06/2024 16:20:22 INFO 140464643696448] Epoch[29] Batch [300]#011Speed: 197.121 samples/sec#011accuracy=0.996366
# [10/06/2024 16:20:24 INFO 140464643696448] Epoch[29] Train-accuracy=0.996194
# [10/06/2024 16:20:24 INFO 140464643696448] Epoch[29] Time cost=50.489
# [10/06/2024 16:20:25 INFO 140464643696448] Epoch[29] Validation-accuracy=0.817708
#
# 2024-10-06 16:20:30 Uploading - Uploading generated training model
# 2024-10-06 16:20:43 Completed - Training job completed
# Training seconds: 1840
# Billable seconds: 1840
# Model training started

# %% [markdown]
# If all goes well, you'll end up with a model topping out above `.8` validation accuracy. With only 1000 training samples in the CIFAR dataset, that's pretty good. We could definitely pursue data augmentation & gathering more samples to help us improve further, but for now let's proceed to deploy our model.
#
# ### Getting ready to deploy
#
# To begin with, let's configure Model Monitor to track our deployment. We'll define a `DataCaptureConfig` below:

# %%
from sagemaker.model_monitor import DataCaptureConfig

# Correctly configure the data capture options
data_capture_config = DataCaptureConfig(
    destination_s3_uri=f"s3://{bucket}/data_capture",  # S3 location to store captured data
    capture_options=["Input", "Output"],  # Capture both input and output data
    sampling_percentage=100,  # Capture 100% of the data
    enable_capture=True  # Enable data capture
)

print("Data capture configuration set up!")
# Out:
# Data capture configuration set up!

# %% [markdown]
# Note the `destination_s3_uri` parameter: At the end of the project, we can explore the `data_capture` directory in S3 to find crucial data about the inputs and outputs Model Monitor has observed on our model endpoint over time.
#
# With that done, deploy your model on a single `ml.m5.xlarge` instance with the data capture config attached:

# %%
endpoint_name = 'image-prediction-udacity-04'
deployment = img_classifier_model.deploy(
    ## TODO: fill in deployment options
        initial_instance_count=1,
        instance_type='ml.m5.xlarge',
        endpoint_name=endpoint_name,
        data_capture_config=data_capture_config,
    )
# Out:
# INFO:sagemaker:Creating model with name: image-classification-2024-10-06-17-36-05-148
# INFO:sagemaker:Creating endpoint-config with name image-prediction-udacity-04
# INFO:sagemaker:Creating endpoint with name image-prediction-udacity-04
# -----------!

# %%
endpoint = deployment.endpoint_name
print(endpoint)
# Out:
# image-prediction-udacity-04

# %% [markdown]
# Note the endpoint name for later as well.
#
# Next, instantiate a Predictor:

# %%
predictor = sagemaker.Predictor(endpoint_name='image-prediction-udacity-03')

# %% [markdown]
# In the code snippet below we are going to prepare one of your saved images for prediction. Use the predictor to process the `payload`.

# %%
from sagemaker.serializers import IdentitySerializer
import base64

predictor.serializer = IdentitySerializer("image/png")
with open("./test/motorbike_s_000465.png", "rb") as f:
    payload = f.read()

    
inference = predictor.predict(payload)## TODO: Process the payload with your predictor
inference
# Out:
# b'[0.992887556552887, 0.007112479768693447]'

# %% [markdown]
# Your `inference` object is an array of two values, the predicted probability value for each of your classes (bicycle and motorcycle respectively.) So, for example, a value of `b'[0.91, 0.09]'` indicates the probability of being a bike is 91% and being a motorcycle is 9%.

# %%
print(f"inference result: {inference}")
# Out:
# inference result: b'[0.9964981079101562, 0.0035018823109567165]'

# %% [markdown]
# ### Draft Lambdas and Step Function Workflow
#
# Your operations team uses Step Functions to orchestrate serverless workflows. One of the nice things about Step Functions is that [workflows can call other workflows](https://docs.aws.amazon.com/step-functions/latest/dg/connect-stepfunctions.html), so the team can easily plug your workflow into the broader production architecture for Scones Unlimited.
#
# In this next stage you're going to write and deploy three Lambda functions, and then use the Step Functions visual editor to chain them together! Our functions are going to work with a simple data object:
#
# ```python
# {
#     "inferences": [], # Output of predictor.predict
#     "s3_key": "", # Source data S3 key
#     "s3_bucket": "", # Source data S3 bucket
#     "image_data": ""  # base64 encoded string containing the image data
# }
# ```
#
# A good test object that you can use for Lambda tests and Step Function executions, throughout the next section, might look like this:
#
# ```python
# {
#   "image_data": "",
#   "s3_bucket": MY_BUCKET_NAME, # Fill in with your bucket
#   "s3_key": "test/bicycle_s_000513.png"
# }
# ```
#
# Using these fields, your functions can read and write the necessary data to execute your workflow. Let's start with the first function. Your first Lambda function will copy an object from S3, base64 encode it, and then return it to the step function as `image_data` in an event.
#
# Go to the Lambda dashboard and create a new Lambda function with a descriptive name like "serializeImageData" and select thr 'Python 3.8' runtime. Add the same permissions as the SageMaker role you created earlier. (Reminder: you do this in the Configuration tab under "Permissions"). Once you're ready, use the starter code below to craft your Lambda handler:
#
# ```python
# import json
# import boto3
# import base64
#
# s3 = boto3.client('s3')
#
# def lambda_handler(event, context):
#     """A function to serialize target data from S3"""
#
#     # Get the s3 address from the Step Function event input
#     key = ## TODO: fill in
#     bucket = ## TODO: fill in
#
#     # Download the data from s3 to /tmp/image.png
#     ## TODO: fill in
#
#     # We read the data from a file
#     with open("/tmp/image.png", "rb") as f:
#         image_data = base64.b64encode(f.read())
#
#     # Pass the data back to the Step Function
#     print("Event:", event.keys())
#     return {
#         'statusCode': 200,
#         'body': {
#             "image_data": image_data,
#             "s3_bucket": bucket,
#             "s3_key": key,
#             "inferences": []
#         }
#     }
# ```
#
# The next function is responsible for the classification part - we're going to take the image output from the previous function, decode it, and then pass inferences back to the the Step Function.
#
# Because this Lambda will have runtime dependencies (i.e. the SageMaker SDK) you'll need to package them in your function. *Key reading:* https://docs.aws.amazon.com/lambda/latest/dg/python-package-create.html#python-package-create-with-dependency
#
# Create a new Lambda function with the same rights and a descriptive name, then fill in the starter code below for your classifier Lambda.
#
# ```python
# import json
# import sagemaker
# import base64
# from sagemaker.serializers import IdentitySerializer
#
# # Fill this in with the name of your deployed model
# ENDPOINT = ## TODO: fill in
#
# def lambda_handler(event, context):
#
#     # Decode the image data
#     image = base64.b64decode(## TODO: fill in)
#
#     # Instantiate a Predictor
#     predictor = ## TODO: fill in
#
#     # For this model the IdentitySerializer needs to be "image/png"
#     predictor.serializer = IdentitySerializer("image/png")
#
#     # Make a prediction:
#     inferences = ## TODO: fill in
#
#     # We return the data back to the Step Function
#     event["inferences"] = inferences.decode('utf-8')
#     return {
#         'statusCode': 200,
#         'body': json.dumps(event)
#     }
# ```
#
# Finally, we need to filter low-confidence inferences. Define a threshold between 1.00 and 0.000 for your model: what is reasonble for you? If the model predicts at `.70` for it's highest confidence label, do we want to pass that inference along to downstream systems? Make one last Lambda function and tee up the same permissions:
#
# ```python
# import json
#
#
# THRESHOLD = .93
#
#
# def lambda_handler(event, context):
#
#     # Grab the inferences from the event
#     inferences = ## TODO: fill in
#
#     # Check if any values in our inferences are above THRESHOLD
#     meets_threshold = ## TODO: fill in
#
#     # If our threshold is met, pass our data back out of the
#     # Step Function, else, end the Step Function with an error
#     if meets_threshold:
#         pass
#     else:
#         raise("THRESHOLD_CONFIDENCE_NOT_MET")
#
#     return {
#         'statusCode': 200,
#         'body': json.dumps(event)
#     }
# ```
# Once you have tested the lambda functions, save the code for each lambda function in a python script called 'lambda.py'.
#
# With your lambdas in place, you can use the Step Functions visual editor to construct a workflow that chains them together. In the Step Functions console you'll have the option to author a Standard step function *Visually*.
#
# When the visual editor opens, you'll have many options to add transitions in your workflow. We're going to keep it simple and have just one: to invoke Lambda functions. Add three of them chained together. For each one, you'll be able to select the Lambda functions you just created in the proper order, filter inputs and outputs, and give them descriptive names.
#
# Make sure that you:
#
# 1. Are properly filtering the inputs and outputs of your invokations (e.g. `$.body`)
# 2. Take care to remove the error handling from the last function - it's supposed to "fail loudly" for your operations colleagues!
#
# Take a screenshot of your working step function in action and export the step function as JSON for your submission package.

# %% [markdown]
# Great! Now you can use the files in `./test` as test files for our workflow. Depending on our threshold, our workflow should reliably pass predictions about images from `./test` on to downstream systems, while erroring out for inferences below our confidence threshold!
#
# ### Testing and Evaluation
#
# Do several step function invokations using data from the `./test` folder. This process should give you confidence that the workflow both *succeeds* AND *fails* as expected. In addition, SageMaker Model Monitor will generate recordings of your data and inferences which we can visualize.
#
# Here's a function that can help you generate test inputs for your invokations:

# %%
import random
import boto3
import json


def generate_test_case():
    # Setup s3 in boto3
    s3 = boto3.resource('s3')
    
    # Randomly pick from sfn or test folders in our bucket
    collections = s3.Bucket(bucket).objects
    objects = collections.filter(Prefix="test")
    
    # Grab any random object key from that folder!
    obj = random.choice([x.key for x in objects])
    
    return json.dumps({
        "image_data": "",
        "s3_bucket": bucket,
        "s3_key": obj
    })
generate_test_case()
# Out:
# '{"image_data": "", "s3_bucket": "sagemaker-us-east-1-072298625118", "s3_key": "test/motorcycle_s_000739.png"}'

# %% [markdown]
# In the Step Function dashboard for your new function, you can create new executions and copy in the generated test cases. Do several executions so that you can generate data you can evaluate and visualize.
#
# Once you've done several executions, let's visualize the record of our inferences. Pull in the JSONLines data from your inferences like so:

# %%
from sagemaker.s3 import S3Downloader

# In S3 your data will be saved to a datetime-aware path
# Find a path related to a datetime you're interested in
data_path = f"s3://{bucket}/data_capture" # fill in the path to your captured data

S3Downloader.download(data_path, "captured_data")

# Feel free to repeat this multiple times and pull in more data
# Out:
# ['captured_data/image-prediction-udacity-02/AllTraffic/2024/10/05/05/24-56-843-8c973b03-5bc8-40ec-8719-c7d4e243100b.jsonl',
#  'captured_data/image-prediction-udacity-02/AllTraffic/2024/10/05/05/29-55-098-43235bdf-8539-44e1-af38-82754092ddb1.jsonl',
#  'captured_data/image-prediction-udacity-03/AllTraffic/2024/10/06/22/13-16-650-427281a8-699f-489a-9294-c171e55c5fdb.jsonl',
#  'captured_data/image-prediction-udacity-03/AllTraffic/2024/10/06/22/14-24-694-fdd14815-630e-4eea-bea8-01cf0bfc1705.jsonl',
#  'captured_data/image-prediction-udacity-03/AllTraffic/2024/10/06/22/15-46-610-8a7c52de-fbe2-4a89-a0a5-ca01e583153e.jsonl']

# %% [markdown]
# The data are in JSONLines format, where multiple valid JSON objects are stacked on top of eachother in a single `jsonl` file. We'll import an open-source library, `jsonlines` that was purpose built for parsing this format.

# %%
# !pip install jsonlines
import jsonlines
# Out:
# Collecting jsonlines
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: attrs>=19.2.0 in /opt/conda/lib/python3.10/site-packages (from jsonlines) (23.2.0)
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Installing collected packages: jsonlines
# Successfully installed jsonlines-4.0.0

# %% [markdown]
# Now we can extract the data from each of the source files:

# %%
import os

# List the file names we downloaded
file_handles = os.listdir("./captured_data")

# Dump all the data into an array
json_data = []
for jsonl in file_handles:
    with jsonlines.open(f"./captured_data/{jsonl}") as f:
        json_data.append(f.read())

# %% [markdown]
# The data should now be a list of dictionaries, with significant nesting. We'll give you an example of some code that grabs data out of the objects and visualizes it:

# %%
# Define how we'll get our data
def simple_getter(obj):
    inferences = obj["captureData"]["endpointOutput"]["data"]
    timestamp = obj["eventMetadata"]["inferenceTime"]
    return json.loads(inferences), timestamp

simple_getter(json_data[0])
# Out:
# ([0.8978920578956604,
#   0.10209845751523972,
#   6.843597333272555e-08,
#   4.6052516466943416e-08,
#   5.8555713167152135e-08,
#   6.315762846043071e-08,
#   6.596844315254202e-08,
#   6.405819164001514e-08,
#   7.374978849838953e-08,
#   6.569634081188269e-08,
#   7.02928559803695e-08,
#   3.0667468564615774e-08,
#   6.805393581998942e-08,
#   6.462614976499026e-08,
#   6.783543682331583e-08,
#   5.988203355400401e-08,
#   6.791272966211181e-08,
#   6.23564915258612e-08,
#   3.418796268306323e-08,
#   6.025175025570206e-08,
#   5.197553676339339e-08,
#   6.343312719536698e-08,
#   6.611581682136602e-08,
#   5.697431859630342e-08,
#   6.515115558158868e-08,
#   7.059557560751273e-08,
#   6.613865366489335e-08,
#   5.3143999423355126e-08,
#   6.63550991930606e-08,
#   5.491459731388204e-08,
#   6.124039231281131e-08,
#   6.174932565272684e-08,
#   7.43616794807167e-08,
#   7.210447705574552e-08,
#   5.5192021619632214e-08,
#   6.478510528040715e-08,
#   6.780762618063818e-08,
#   6.392637175167692e-08,
#   6.515811890039913e-08,
#   7.226680764915727e-08,
#   6.753309378382255e-08,
#   6.004249542002071e-08,
#   6.455223200418914e-08,
#   6.608543401398492e-08,
#   5.470613828606474e-08,
#   5.833577176872495e-08,
#   6.349752368350892e-08,
#   6.063195456817994e-08,
#   5.7187047985962636e-08,
#   6.602017776913272e-08,
#   6.920095785289959e-08,
#   5.9505744332000177e-08,
#   6.739309554859574e-08,
#   7.281457214958209e-08,
#   7.144313229900945e-08,
#   6.93156181341692e-08,
#   6.39242969668885e-08,
#   7.090122267072729e-08,
#   6.317220879736851e-08,
#   5.236660172158736e-08,
#   6.888806325378027e-08,
#   3.8405875812941304e-08,
#   6.028692212112219e-08,
#   5.1683020529935675e-08,
#   6.546855502165272e-08,
#   6.767945137653442e-08,
#   6.584562584066589e-08,
#   6.5877280519544e-08,
#   6.382159511986174e-08,
#   6.85521186483129e-08,
#   5.937230795893811e-08,
#   7.190972439730103e-08,
#   6.221226556135662e-08,
#   6.617006675924131e-08,
#   6.971644239683883e-08,
#   5.658973023514591e-08,
#   5.524267621126455e-08,
#   6.439347544073826e-08,
#   6.782703110275179e-08,
#   5.964232485666798e-08,
#   5.7561749144952046e-08,
#   6.072917102528663e-08,
#   6.829032628274945e-08,
#   6.801812446610711e-08,
#   6.793773366098321e-08,
#   5.666122859793177e-08,
#   7.416338121402077e-08,
#   7.214258346266433e-08,
#   5.998846575039352e-08,
#   6.492600590490838e-08,
#   6.594655133085325e-08,
#   6.824826925821981e-08,
#   6.990018874830639e-08,
#   6.793501228230525e-08,
#   7.078474340005414e-08,
#   4.5423277583722665e-08,
#   6.695324827887816e-08,
#   5.7588767532479324e-08,
#   6.781849748449531e-08,
#   4.983055745810816e-08],
#  '2024-10-05T05:24:56Z')

# %% [markdown]
# Finally, here's an example of a visualization you can build with this data. In this last part, you will take some time and build your own - the captured data has the input images, the resulting inferences, and the timestamps.

# %%
# Populate the data for the x and y axis
x = []
y = []
for obj in json_data:
    inference, timestamp = simple_getter(obj)
    
    y.append(max(inference))
    x.append(timestamp)

# Todo: here is an visualization example, take some time to build another visual that helps monitor the result
# Plot the data
plt.scatter(x, y, c=['r' if k<.94 else 'b' for k in y ])
plt.axhline(y=0.94, color='g', linestyle='--')
plt.ylim(bottom=.88)

# Add labels
plt.ylabel("Confidence")
plt.suptitle("Observed Recent Inferences", size=14)
plt.title("Pictured with confidence threshold for production use", size=10)

# Give it some pizzaz!
plt.style.use("Solarize_Light2")
plt.gcf().autofmt_xdate()
# Out:
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %% [markdown]
# ### Todo: build your own visualization

# %% [markdown]
# ### Congratulations!
#
# You've reached the end of the project. In this project you created an event-drivent ML workflow that can be incorporated into the Scones Unlimited production architecture. You used the SageMaker Estimator API to deploy your SageMaker Model and Endpoint, and you used AWS Lambda and Step Functions to orchestrate your ML workflow. Using SageMaker Model Monitor, you instrumented and observed your Endpoint, and at the end of the project you built a visualization to help stakeholders understand the performance of the Endpoint over time. If you're up for it, you can even go further with these stretch goals:
#
# * Extend your workflow to incorporate more classes: the CIFAR dataset includes other vehicles that Scones Unlimited can identify with this model.
# * Modify your event driven workflow: can you rewrite your Lambda functions so that the workflow can process multiple image inputs in parallel? Can the Step Function "fan out" to accomodate this new workflow?
# * Consider the test data generator we provided for you. Can we use it to create a "dummy data" generator, to simulate a continuous stream of input data? Or a big paralell load of data?
# * What if we want to get notified every time our step function errors out? Can we use the Step Functions visual editor in conjunction with a service like SNS to accomplish this? Try it out!
